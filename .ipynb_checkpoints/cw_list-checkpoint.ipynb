# %%
import os
import json
import requests
import random

from django.core.files.base import ContentFile
from shop.models import Category, Shop, Item
from urllib.parse import urljoin
from fake_useragent import UserAgent

# %%
class food_date:
    HOST = 'https://www.yogiyo.co.kr'
    
    def __init__(self, headers):
        self.headers = headers
        
    def get_restaurant_list_by_geo(self, zip_code):
        url = self.HOST + '/api/v1/restaurants-geo/'
        
        params = dict(
            items=20,
            lat=37.5495123860853,
            lng=127.047075859646,
            order='rank',
            page=0,
            search='',
            zip_code=zip_code,
        )
        
        res = requests.get(url, params=params, headers=self.headers)
        return res.json()
    
    def get_menu_list(self, restaurant_id):
        base_url = self.HOST + '/api/v1/restaurants/{restaurant_id}/menu/?add_photo_menu=original'
        url = base_url.format(restaurant_id=restaurant_id)
        res = requests.get(url, headers=self.headers)
        return res.json()

# %%
user_agent = UserAgent()

# %%
headers = {
    'x-apikey': 'iphoneap',
    'x-apisecret': 'fe5183cc3dea12bd0ce299cf110a75a2',
    'User_Agent': user_agent.Chrome,
}

# %%
headers
# Out:
# {'x-apikey': 'iphoneap',
#  'x-apisecret': 'fe5183cc3dea12bd0ce299cf110a75a2',
#  'User_Agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.16 Safari/537.36'}

# %%
food = food_date(headers)

# %%
zip_code = '143201'
restaurants = food.get_restaurant_list_by_geo('143201')['restaurants']
restaurants
# Out:
# [{'rating': 200033.546182716,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 50000,
#   'delivery_fee_explanation': '주문 금액이 50000원 이하일 경우 배달 요금 1000원이 부과됩니다',
#   'is_available_delivery': True,
#   'threshold': 9000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 864,
#   'sms_bonus': True,
#   'franchise_id': 405,
#   'phone_downlisted': False,
#   'franchise_name': '주식회사정담F&B / 배달삼겹돼지되지',
#   'review_image_count': 508,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '오리지날 솔로, 양념 솔로',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712910607',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['한식'],
#   'min_order_amount': 14500,
#   'distance': 4.046234472426466,
#   'logo_url': '/media/franchise_logos/배달삼겹돼지되지_20171122_Franchise이미지약정서_crop_200x200_isnQp2N.jpg',
#   'except_cash': False,
#   'name': '배달삼겹돼지되지-구의점',
#   'section_pos': 1,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 23:00',
#   'keywords': '배달삼겹돼지되지-구의점 오리지날메뉴 오리지날솔로 양념메뉴 양념솔로 오리지날메뉴 오리지날小 반반메뉴 반반小 오리지날메뉴 오리지날中 반반메뉴 반반中 추가메뉴 공기밥 오리지날메뉴 오리지날大 양념메뉴 양념小 주류 참이슬후레쉬',
#   'new_rating': 0.556956378683744,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.092347494384,
#   'list_pos': 1,
#   'id': 250260,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 876,
#   'owner_reply_count': 864,
#   'section': 'superlist',
#   'loyal_score': 13.9239094670936,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20180919180821263068_%EC%A0%9C%ED%9C%B4FR_20180918_%EB%B0%B0%EB%8B%AC%EC%82%BC%EA%B2%B9%EB%8F%BC%EC%A7%80%EB%90%98%EC%A7%80_%EB%8C%80%ED%91%9C%EC%9D%B4%EB%AF%B8%EC%A7%80_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 구의동 203-13 1층',
#   'lat': 37.5435328805089,
#   'end': '23:00:00',
#   'slug': '배달삼겹돼지되지-구의점',
#   'review_avg': 4.72945205479452,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200033.644549426,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2019-06-25T22:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 868,
#   'sms_bonus': False,
#   'franchise_id': 4,
#   'phone_downlisted': False,
#   'franchise_name': '(주)7번가사람들 / 7번가피자',
#   'review_image_count': 352,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '슈퍼콤비네이션 R, 페페로니 R',
#   'additional_discount_per_menu': 3000,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352597043',
#   'additional_discount_only_for_user': True,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 15000,
#   'distance': 1.2750404523762071,
#   'logo_url': '/media/franchise_logos/7번가피자_20160205_Franchise이미지약정서_crop_200x200_PXVSv6U.jpg',
#   'except_cash': False,
#   'name': '7번가피자-한양대점',
#   'section_pos': 1,
#   'relay_methods': ['email', 'relayo_relay', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 23:00',
#   'keywords': '7번가피자-한양대점 오리지널R 슈퍼콤비네이션R 오리지널R 흥부포테이토R 오리지널R 페페로니R 사이드 오븐스파게티 오리지널L 슈퍼콤비네이션L 사이드 핫윙（4PCS） 사이드 디핑소스 프리미엄스페셜R 홍대피자R 사이드 치즈볼（8PCS） 프리미엄스페셜R 체다골드포테이토R',
#   'new_rating': 1.0278201828487348,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0431297,
#   'list_pos': 2,
#   'id': 237355,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 868,
#   'owner_reply_count': 868,
#   'section': 'hotdeal',
#   'loyal_score': 17.0707068330994,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181018163336282782_%EC%A0%9C%ED%9C%B4FR_20181017_7%EB%B2%88%EA%B0%80%ED%94%BC%EC%9E%90_%EB%B0%B0%EA%B2%BD%ED%99%94%EB%A9%B4_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO', 'relayo'],
#   'address': '서울특별시 성동구 사근동 309-28 1층 101호',
#   'lat': 37.5605440999408,
#   'end': '23:00:00',
#   'slug': '7번가피자-행당점',
#   'review_avg': 4.69585253456221,
#   'discount_from': '2019-06-25T14:00:00',
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200028.860041331,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 10000원',
#   'is_available_delivery': True,
#   'threshold': 7500,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 2,
#   'sms_bonus': False,
#   'franchise_id': 475,
#   'phone_downlisted': False,
#   'franchise_name': '(주)에스피씨클라우드 / 파리바게뜨',
#   'review_image_count': 27,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '아이스 아메리카노（오리지널）, 우유가 좋은 뽀로로케익',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '0000000000',
#   'additional_discount_only_for_user': True,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '카페디저트'],
#   'min_order_amount': 10000,
#   'distance': 0.7596145344825384,
#   'logo_url': '/media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg',
#   'except_cash': True,
#   'name': '파리바게뜨-뚝섬점',
#   'section_pos': 2,
#   'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': False,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:20 - 22:30',
#   'keywords': '파리바게뜨-뚝섬점 빵／식빵 찹쌀도넛 음료／커피 아이스아메리카노（오리지널） 빵／식빵 초코소라빵 빵／식빵 후레쉬크림샌드빵 빵／식빵 추억의소시지빵 샌드위치／샐러드／가정간편식（HMR） 런치샌드위치 샌드위치／샐러드／가정간편식（HMR） 단백질듬뿍로스트치킨샐러드 빵／식빵 쫄깃한피자빵 빵／식빵 블루베리베이글 빵／식빵 단팥빵',
#   'new_rating': 1.0078981011652803,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.042797084697,
#   'list_pos': 3,
#   'id': 299077,
#   'can_review': 0,
#   'estimated_delivery_time': '50~60분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 62,
#   'owner_reply_count': 2,
#   'section': 'hotdeal',
#   'loyal_score': 13.9955252015447,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181226172215790527_%EC%A0%9C%ED%9C%B4FR_20181226_%ED%8C%8C%EB%A6%AC%EB%B0%94%EA%B2%8C%EB%9C%A8_%EB%B0%B0%EA%B2%BD%EC%82%AC%EC%A7%84_1080x640.png',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:20:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 성동구 성수동1가 660-14',
#   'lat': 37.5435828908105,
#   'end': '22:30:00',
#   'slug': '파리바게뜨-뚝섬점',
#   'review_avg': 4.90322580645161,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['online']},
#  {'rating': 200029.659743491,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 26500원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 41,
#   'phone_downlisted': False,
#   'franchise_name': '한국파파존스(주) / 파파존스',
#   'review_image_count': 32,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '수퍼 파파스 오리지널 크러스트 R, 수퍼 파파스 오리지널 크러스트 L',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352597617',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 26500,
#   'distance': 0.28851457141669595,
#   'logo_url': '/media/franchise_logos/파파존스_20170313_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '파파존스-성수점',
#   'section_pos': 3,
#   'relay_methods': ['email', 'box_helicom'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:00',
#   'keywords': '파파존스-성수점 음료 코카콜라1.25L 오리지널크러스트라지（L） 수퍼파파스오리지널크러스트L 오리지널크러스트레귤러（R） 수퍼파파스오리지널크러스트R 소스 갈릭소스 사이드 파파스파스타（미트） 소스 핫소스 오리지널크러스트레귤러（R） 올미트오리지널크러스트R 사이드 파파스윙 오리지널크러스트라지（L） 존스페이버릿오리지널크러스트L 음료 코카콜라500mL',
#   'new_rating': 0.9749789601870409,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0447483,
#   'list_pos': 4,
#   'id': 237882,
#   'can_review': 0,
#   'estimated_delivery_time': '35~45분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 181,
#   'owner_reply_count': 0,
#   'section': 'hotdeal',
#   'loyal_score': 10.8170468617595,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190125170555450837_%EC%A0%9C%ED%9C%B4FR_20190125_%ED%8C%8C%ED%8C%8C%EC%A1%B4%EC%8A%A4_%EB%B0%B0%EA%B2%BD%EC%82%AC%EC%A7%84_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 6000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 성동구 성수동1가 656-297 2층 202호',
#   'lat': 37.5476884,
#   'end': '22:00:00',
#   'slug': '파파존스-성수점',
#   'review_avg': 4.49171270718232,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200021.286889431,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 21900원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 3,
#   'sms_bonus': False,
#   'franchise_id': 652,
#   'phone_downlisted': False,
#   'franchise_name': '(주)청오디피케이 / 도미노피자',
#   'review_image_count': 9,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '포테이토 피자（오리지널 도우 L）, 페퍼로니 피자（오리지널 도우 L）',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712976456',
#   'additional_discount_only_for_user': True,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 21900,
#   'distance': 0.9484943439206425,
#   'logo_url': '/media/franchise_logos/도미노피자_20190102_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': True,
#   'name': '도미노피자-성수2호점',
#   'section_pos': 4,
#   'relay_methods': ['email', 'relayo_relay', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:00',
#   'keywords': '도미노피자-성수2호점 음료 코카콜라1.25L 오리지널도우 포테이토피자（오리지널도우L） 오리지널도우 페퍼로니피자（오리지널도우L） 나폴리도우 포테이토피자（나폴리도우L） 슈퍼시드함유도우 콰트로치즈퐁듀피자（슈퍼시드함유도우L） 나폴리도우 페퍼로니피자（나폴리도우L） 더블크러스트 더블크러스트이베리코피자（L） 음료 코카콜라500ml 오리지널도우 슈퍼디럭스피자（오리지널도우L） 슈퍼시드함유도우 블랙앵거스스테이크피자with랍스터볼（슈퍼시드함유도우L）',
#   'new_rating': 0.8364433751416396,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0477029377,
#   'list_pos': 5,
#   'id': 319812,
#   'can_review': 0,
#   'estimated_delivery_time': '35~45분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 22,
#   'owner_reply_count': 3,
#   'section': 'hotdeal',
#   'loyal_score': 10.6535560981442,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 5000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO', 'relayo'],
#   'address': '서울 성동구 성수동1가 656-365 1층 12,13,14호',
#   'lat': 37.5409968739098,
#   'end': '22:00:00',
#   'slug': '도미노피자-성수2호점',
#   'review_avg': 4.31818181818182,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['online']},
#  {'rating': 200019.81034434,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15900원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 52,
#   'sms_bonus': False,
#   'franchise_id': 85,
#   'phone_downlisted': False,
#   'franchise_name': '한국피자헛유한회사 / 피자헛',
#   'review_image_count': 92,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '리치골드 베이컨포테이토M 세트, 리치골드 수퍼슈프림M 세트',
#   'additional_discount_per_menu': 13000,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352588449',
#   'additional_discount_only_for_user': True,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 15900,
#   'distance': 0.9038128466069135,
#   'logo_url': '/media/franchise_logos/피자헛_20170612_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '피자헛-성수점',
#   'section_pos': 5,
#   'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:30',
#   'keywords': '피자헛-성수점 사이드메뉴 치즈크러스트디핑소스 사이드메뉴 핫소스 음료 콜라（펩시）1.25L 사이드메뉴 바른생피클L 프리미엄피자-치즈크러스트（30%할인） 수퍼슈프림L（30%할인가） 음료 사이다（칠성）1.25L 프리미엄피자-리치골드（30%할인） 갈릭마블스테이크L（30%할인가） 사이드메뉴 리치치즈파스타 추천세트메뉴 리치골드베이컨포테이토M세트 추천세트메뉴 리치골드수퍼슈프림M세트',
#   'new_rating': 0.5585312042904106,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0570925,
#   'list_pos': 6,
#   'id': 229800,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 377,
#   'owner_reply_count': 52,
#   'section': 'hotdeal',
#   'loyal_score': 3.48234434029483,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181005121914935836_%EC%A0%9C%ED%9C%B4FR_20181004_%ED%94%BC%EC%9E%90%ED%97%9B_%EB%B0%B0%EA%B2%BD%ED%99%94%EB%A9%B4_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO', 'relayo'],
#   'address': '서울 성동구 성수동2가 289-5 101-1호 APEX CENTER',
#   'lat': 37.5477805999392,
#   'end': '22:30:00',
#   'slug': '피자헛-뚝섬2호점',
#   'review_avg': 4.52254641909814,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200024.724140695,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 16000원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 15,
#   'sms_bonus': False,
#   'franchise_id': 80,
#   'phone_downlisted': False,
#   'franchise_name': '주식회사엠피그룹 / 미스터피자',
#   'review_image_count': 40,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '새우천왕L, 포테이토골드L',
#   'additional_discount_per_menu': 10000,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712906158',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 16000,
#   'distance': 1.7284482202454927,
#   'logo_url': '/media/franchise_logos/미스터피자_20170417_Franchise이미지약정서_crop_200x200.JPG',
#   'except_cash': False,
#   'name': '미스터피자-성수점',
#   'section_pos': 6,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:00',
#   'keywords': '미스터피자-성수점 음료&소스 갈릭디핑소스 음료&소스 핫소스 파스타&라이스 오븐치즈미트스파게티 프리미엄L 새우천왕L 프리미엄L 포테이토골드L 샐러드 홈샐러드 프리미엄L 치우천왕L 파스타&라이스 오븐치즈베이컨크림스파게티 클래식L 슈퍼콤보L 클래식R 포테이토R',
#   'new_rating': 0.4693449492480559,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0595077,
#   'list_pos': 7,
#   'id': 245962,
#   'can_review': 0,
#   'estimated_delivery_time': '50~60분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 174,
#   'owner_reply_count': 15,
#   'section': 'hotdeal',
#   'loyal_score': 5.37586483242886,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190214172344777046_%EC%A0%9C%ED%9C%B4FR_20190214_%EB%AF%B8%EC%8A%A4%ED%84%B0%ED%94%BC%EC%9E%90_%EB%B0%B0%EA%B2%BD%EC%82%AC%EC%A7%84_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 성동구 성수동2가 230-9 우신빌딩1층',
#   'lat': 37.5374931,
#   'end': '22:00:00',
#   'slug': '미스터피자-성수점',
#   'review_avg': 4.53448275862069,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200014.41496266,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 13500원',
#   'is_available_delivery': True,
#   'threshold': 7500,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 360,
#   'phone_downlisted': False,
#   'franchise_name': '(주)에스피씨클라우드 / 배스킨라빈스',
#   'review_image_count': 36,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '쿼터, 패밀리',
#   'additional_discount_per_menu': 2000,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '0000000000',
#   'additional_discount_only_for_user': True,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '카페디저트'],
#   'min_order_amount': 13500,
#   'distance': 0.2857316540330217,
#   'logo_url': '/media/franchise_logos/배스킨라빈스_20161130_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': True,
#   'name': '배스킨라빈스-서울숲점',
#   'section_pos': 7,
#   'relay_methods': ['email', 'relayo_relay', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': False,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:00',
#   'keywords': '배스킨라빈스-서울숲점 핸드팩세트 쿼터 핸드팩세트 패밀리 핸드팩세트 파인트 핸드팩세트 하프갤런 기프트세트 버라이어티팩 디저트세트 스노우모찌그린티 디저트세트 아이스마카롱쿠키앤크림 디저트세트 아이스마카롱체리쥬빌레 디저트세트 스노우모찌콩고물\xa0 디저트세트 아이스초코파이마시멜로&초콜릿',
#   'new_rating': 0.4552905594210036,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.044740217848,
#   'list_pos': 8,
#   'id': 248988,
#   'can_review': 0,
#   'estimated_delivery_time': '50~60분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 99,
#   'owner_reply_count': 0,
#   'section': 'hotdeal',
#   'loyal_score': -2.1890777443098,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190104155929495742_%EC%A0%9C%ED%9C%B4FR_20190104_%EB%B0%B0%EC%8A%A4%ED%82%A8%EB%9D%BC%EB%B9%88%EC%8A%A4_%EB%B0%B0%EA%B2%BD%EC%82%AC%EC%A7%84_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 성동구 성수동1가 656-297 신한빌딩 1층',
#   'lat': 37.5477308172463,
#   'end': '22:00:00',
#   'slug': '배스킨라빈스-서울숲점',
#   'review_avg': 4.71717171717172,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['online']},
#  {'rating': 200018.952835213,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1000원, 최소 주문 금액 20000원',
#   'is_available_delivery': True,
#   'threshold': 9000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 46,
#   'sms_bonus': True,
#   'franchise_id': 57,
#   'phone_downlisted': False,
#   'franchise_name': '(주)놀부NBG / 놀부부대찌개',
#   'review_image_count': 21,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '놀부부대세트 2인, 놀부부대 2인',
#   'additional_discount_per_menu': 2000,
#   'delivery_fee': 1000,
#   'additional_discount_pickup': 0,
#   'phone': '050352591582',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['한식', '프랜차이즈'],
#   'min_order_amount': 20000,
#   'distance': 1.2546746836456617,
#   'logo_url': '/media/franchise_logos/놀부부대찌개_20190327_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '놀부부대찌개-시그마밸리점',
#   'section_pos': 8,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:40 - 20:50',
#   'keywords': '놀부부대찌개-시그마밸리점 부대찌개세트 놀부부대세트2인 공기밥 공기밥 통핑／사리 햄사리 부대찌개단품 놀부부대2인 통핑세트 통핑놀부세트2인 음료메뉴 콜라355mL¸ 통핑／사리 라면 부대찌개세트 놀부부대세트3인 통핑／사리 수제비 통핑／사리 생라면',
#   'new_rating': 0.37063561465383105,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0550965,
#   'list_pos': 9,
#   'id': 232400,
#   'can_review': 0,
#   'estimated_delivery_time': '25~35분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 141,
#   'owner_reply_count': 46,
#   'section': 'hotdeal',
#   'loyal_score': 0.539263784574085,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181018163932040396_%EC%A0%9C%ED%9C%B4FR_20181017_%EB%86%80%EB%B6%80%EB%B6%80%EB%8C%80%EC%B0%8C%EA%B0%9C_%EB%B0%B0%EA%B2%BD%ED%99%94%EB%A9%B4_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:40:00',
#   'description': '미조리 상태로 포장배달 / 공기밥 및 사리별도',
#   'tags': ['CESCO'],
#   'address': '서울 성동구 성수동2가 325-2 성수동 2가, 107A,B호',
#   'lat': 37.5401916,
#   'end': '20:50:00',
#   'slug': '놀부부대찌개-시그마밸리부대점',
#   'review_avg': 4.17021276595745,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200017.369590394,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 13000원',
#   'is_available_delivery': True,
#   'threshold': 9000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 29,
#   'sms_bonus': True,
#   'franchise_id': 548,
#   'phone_downlisted': False,
#   'franchise_name': '(주)놀부NBG / 쫄면주는삼겹본능',
#   'review_image_count': 22,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '구이삼겹 1인, 구이삼겹 2인',
#   'additional_discount_per_menu': 2000,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712988977',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['한식', '프랜차이즈'],
#   'min_order_amount': 13000,
#   'distance': 1.247599616750586,
#   'logo_url': '/media/franchise_logos/쫄면주는삼겹본능_20180618_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '쫄면주는삼겹본능-시그마밸리점',
#   'section_pos': 9,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:40 - 20:30',
#   'keywords': '쫄면주는삼겹본능-시그마밸리점 구이삼겹 구이삼겹1인 구이삼겹 구이삼겹2인 간장구이삼겹 간장구이삼겹1인 매운구이삼겹 매운구이삼겹1인 간장구이삼겹 간장구이삼겹2인 핵맵싸구이삼겹 핵맵싸삼겹1인 맵싸구이삼겹 맵싸삼겹2인 매운구이삼겹 매운구이삼겹2인 맵싸구이삼겹 맵싸삼겹1인 맵싸구이삼겹 맵싸주먹밥세트',
#   'new_rating': 0.3029188648229291,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.055100697981,
#   'list_pos': 10,
#   'id': 332901,
#   'can_review': 0,
#   'estimated_delivery_time': '55~65분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 31,
#   'owner_reply_count': 29,
#   'section': 'hotdeal',
#   'loyal_score': -1.18903029567384,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:40:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 성동구 성수동2가 325-2 서울숲한라시그마벨리 107A,B호',
#   'lat': 37.5402710166844,
#   'end': '20:30:00',
#   'slug': '쫄면주는삼겹본능-시그마밸리점',
#   'review_avg': 4.12903225806452,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200012.41605253,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 15000원',
#   'is_available_delivery': True,
#   'threshold': 9000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2019-06-25T20:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 65,
#   'phone_downlisted': False,
#   'franchise_name': '(주)원앤원 / 박가부대',
#   'review_image_count': 42,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '오리지널부대찌개, 요기요 수제햄세트 2인（수제햄부대찌개 2인 ＋ 콜라）',
#   'additional_discount_per_menu': 2000,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050352584275',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '한식'],
#   'min_order_amount': 15000,
#   'distance': 1.0472781544182377,
#   'logo_url': '/media/franchise_logos/박가부대_20180830_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '박가부대-성수코오롱디지털밸리점',
#   'section_pos': 10,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 21:00',
#   'keywords': '박가부대-성수코오롱디지털밸리점 부대찌개메뉴 오리지널부대찌개 부대찌개사리 공기밥 부대찌개메뉴 수제햄부대찌개 부대찌개사리 모둠사리 부대찌개사리 햄소세지사리 부대찌개세트메뉴 수제햄부대찌개2인세트 부대찌개메뉴 박가부대찌개 부대찌개사리 수제햄사리 부대찌개세트메뉴 오리지널부대찌개2인세트 부대찌개사리 우동사리',
#   'new_rating': 0.13873703209765004,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0534298,
#   'list_pos': 11,
#   'id': 225655,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 183,
#   'owner_reply_count': 0,
#   'section': 'hotdeal',
#   'loyal_score': -6.29518342546756,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '조리 전 상태로 배달되며, 끓여 드셔야 합니다.',
#   'tags': [],
#   'address': '서울 성동구 성수동2가 333-140 성수코오롱디지털밸리지하1층 102호',
#   'lat': 37.5415546,
#   'end': '21:00:00',
#   'slug': '박가부대찌개-성수코오롱디지털밸리점',
#   'review_avg': 4.40437158469945,
#   'discount_from': '2019-06-25T17:00:00',
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200012.332118638,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 28000원',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2019-06-25T21:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 109,
#   'sms_bonus': False,
#   'franchise_id': 28,
#   'phone_downlisted': False,
#   'franchise_name': '(주)원앤원 / 원할머니보쌈',
#   'review_image_count': 130,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '모둠보쌈, 솜씨보쌈',
#   'additional_discount_per_menu': 3000,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050352575370',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '족발보쌈'],
#   'min_order_amount': 28000,
#   'distance': 1.2668523393243494,
#   'logo_url': '/media/franchise_logos/원할머니보쌈02_20150716_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '원할머니보쌈-성수점',
#   'section_pos': 11,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:30 - 23:30',
#   'keywords': '원할머니보쌈-성수점 보쌈류 모둠보쌈 보쌈류 솜씨보쌈 세트메뉴 보족원쌈（2인） 족발류 부드러운족발 보쌈류 맛보쌈 세트메뉴 커플원쌈 족발류 반반족발 추가메뉴 공기밥 세트메뉴 보족원쌈（3인） 세트메뉴 보족원쌈（4인）',
#   'new_rating': 0.08815670191506808,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0545404,
#   'list_pos': 12,
#   'id': 54607,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 431,
#   'owner_reply_count': 109,
#   'section': 'hotdeal',
#   'loyal_score': -6.46182075550155,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:30:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 성동구 성수동2가 333-15',
#   'lat': 37.5397772,
#   'end': '23:30:00',
#   'slug': '원할머니보쌈-성수점',
#   'review_avg': 4.45939675174014,
#   'discount_from': '2019-06-25T17:00:00',
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 199980.474613488,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 15000원',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 1,
#   'sms_bonus': False,
#   'franchise_id': 37,
#   'phone_downlisted': False,
#   'franchise_name': '(주)비에이치씨 / BHC치킨',
#   'review_image_count': 286,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '뿌링클, 순살뿌링클',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050352576406',
#   'additional_discount_only_for_user': True,
#   'has_terminal': False,
#   'categories': ['야식', '프랜차이즈', '치킨'],
#   'min_order_amount': 15000,
#   'distance': 0.2077551358741951,
#   'logo_url': '/media/franchise_logos/BHC_20190607_Franchise_crop_200x200.PNG',
#   'except_cash': False,
#   'name': 'BHC-성수점',
#   'section_pos': 12,
#   'relay_methods': ['email', 'relayo_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 23:00',
#   'keywords': 'BHC-성수점 뿌링클 뿌링클 후라이드 해바라기후라이드치킨 맛초킹 맛초킹（한마리） 후라이드 후라이드반／양념반 맵스터 맵스터 후라이드 해바라기핫후라이드치킨 커리퀸 커리퀸 뿌링클 순살뿌링클 사이드／음료 콜라1.25L¸ 맛초킹 순살맛초킹',
#   'new_rating': -0.8756168078761593,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0491796,
#   'list_pos': 13,
#   'id': 218225,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 1108,
#   'owner_reply_count': 1,
#   'section': 'hotdeal',
#   'loyal_score': -35.851644517533,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO', 'relayo'],
#   'address': '서울 성동구 성수동1가 13-162 1층',
#   'lat': 37.5486704,
#   'end': '23:00:00',
#   'slug': 'bhc치킨-성수점',
#   'review_avg': 4.52075812274368,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200053.634217973,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '주문 금액이 10000원 이하일 경우 배달 요금 2500원이 부과됩니다',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 511,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '싱글세트1（탕수육＋짜장）, 짜장면',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352563213',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['중식', '한식', '1인분주문'],
#   'min_order_amount': 10000,
#   'distance': 1.6175289794694256,
#   'logo_url': '/media/restaurant_logos/짜장면01_20120524_FoodAD_crop_200x200_15.jpg',
#   'except_cash': False,
#   'name': '동강',
#   'section_pos': 1,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 20:40',
#   'keywords': '동강 싱글세트 싱글세트1（탕수육＋짜장） 알뜰세트메뉴 1세트（탕수육＋짜장2） 면류 짜장면 면류 간짜장 면류 짬뽕 만두류 군만두 반반메뉴 탕짜면 사이드메뉴 콜라1.25L 싱글세트 싱글세트2（탕수육＋짬뽕） 요리부 탕수육',
#   'new_rating': 1.676041051562163,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0638631,
#   'list_pos': 14,
#   'id': 28628,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 2690,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 34.9886711864012,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/stock_img/%EC%A4%91%EC%8B%9D/%EB%A9%B4%EB%A5%98/%EC%8A%A4%ED%83%81_20181015_foodad_fad02062-left_%EC%A7%9C%EC%9E%A5%EB%A9%B401_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['excellent'],
#   'address': '서울 성동구 성수동2가 277-33번지',
#   'lat': 37.5436425,
#   'end': '20:40:00',
#   'slug': '동강',
#   'review_avg': 4.34052044609665,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200043.059289828,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 14900원',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 31,
#   'phone_downlisted': False,
#   'franchise_name': '(주)제너시스BBQ(비비큐) / BBQ치킨',
#   'review_image_count': 119,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '황금올리브（반반）, 황금올리브치킨',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050352587226',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['치킨', '프랜차이즈'],
#   'min_order_amount': 14900,
#   'distance': 0.13200868394646403,
#   'logo_url': '/media/franchise_logos/BBQ_20160928_Franchise이미지약정서_crop_200x200_AxtSe6b.jpg',
#   'except_cash': False,
#   'name': 'BBQ-성수2점',
#   'section_pos': 2,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '12:00 - 23:59',
#   'keywords': 'BBQ-성수2점 반반치킨 황금올리브（반반） 오리지날치킨 황금올리브치킨 구이치킨 자메이카통다리구이 오리지날치킨 황금올리브닭다리 양념치킨 시크릿양념치킨 옵션 콜라1.25L 옵션 양념소스추가 순살치킨 황금올리브속안심 옵션 코카-콜라1.25L 반반치킨 황금올리브닭다리（반반）',
#   'new_rating': 1.6345969749859832,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0482306,
#   'list_pos': 15,
#   'id': 228961,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 473,
#   'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#   'section': 'contract',
#   'loyal_score': 26.5249677943819,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181228144604231071_%EC%A0%9C%ED%9C%B4FR_20181002_BBQ%EC%B9%98%ED%82%A8_%EB%B0%B0%EA%B2%BD%ED%99%94%EB%A9%B4_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '12:00:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 성동구 성수1가2동 13-78',
#   'lat': 37.5502682,
#   'end': '23:59:00',
#   'slug': 'bbq-성수2점',
#   'review_avg': 4.66807610993657,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200051.977743741,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 11000원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 75,
#   'phone_downlisted': False,
#   'franchise_name': '(주)비케이알 / 버거킹',
#   'review_image_count': 282,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '몬스터X세트, 콰트로치즈와퍼세트',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '0000000000',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 11000,
#   'distance': 2.115331630051918,
#   'logo_url': '/media/franchise_logos/버거킹_20170629_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '버거킹-건대화양점',
#   'section_pos': 3,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': False,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 00:00',
#   'keywords': '버거킹-건대화양점 사이드 텐더킹2조각 사이드 너겟킹4조각 사이드 너겟킹6조각 사이드 21치즈스틱 X,스테이크세트 몬스터X세트 사이드 프렌치프라이（L） 사이드 콘샐러드 사이드 너겟킹10조각 사이드 텐더킹4조각 사이드 어니언링',
#   'new_rating': 1.6234136035750684,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.068494238588,
#   'list_pos': 16,
#   'id': 254883,
#   'can_review': 0,
#   'estimated_delivery_time': '50~60분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 1561,
#   'relay_methods': ['email', 'relayo_relay', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 36.1619982396363,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20180919182822688999_%EC%A0%9C%ED%9C%B4FR_20180918_%EB%B2%84%EA%B1%B0%ED%82%B9_%EB%8C%80%ED%91%9C%EC%9D%B4%EB%AF%B8%EC%A7%80_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': ['relayo', 'excellent'],
#   'address': '서울 광진구 화양동 7-44 단산화빌딩',
#   'lat': 37.5409386584498,
#   'end': '00:00:00',
#   'slug': '버거킹-건대화양점',
#   'review_avg': 4.47533632286996,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200014.0,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1500원, 최소 주문 금액 11000원',
#   'is_available_delivery': True,
#   'threshold': 9000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 0,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '세트（냉모밀＋치즈돈까스）, 세트（냉모밀＋등심돈까스）',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712995139',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['한식', '일식돈까스'],
#   'min_order_amount': 11000,
#   'distance': 2.0858271115590195,
#   'logo_url': '/media/restaurant_logos/냉모밀03_20131128_FoodAD_crop_200x200_oEG5Sxf.jpg',
#   'except_cash': False,
#   'name': '경성돈가스&유부초밥',
#   'section_pos': 4,
#   'relay_methods': ['email', '9cookies'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '16:00 - 21:20',
#   'keywords': '경성돈가스&유부초밥 세트메뉴 세트（냉모밀＋치즈돈까스） 세트메뉴 세트（냉모밀＋등심돈까스） 사이드메뉴 교자5P 유부초밥메뉴 우삼겹유부초밥4P 사이드메뉴 수제등심돈까스1장추가 냉모밀메뉴 강추!냉모밀＋유부초밥3P 세트메뉴 황제VIP셋트!（등심돈까스＋왕새우2p＋치킨4p＋교자5p＋유부초밥4p） 유부초밥메뉴 강추!유부초밥우삼겹2＋새우2P 냉모밀메뉴 냉모밀 사이드메뉴 매콤치킨가라아게4조각',
#   'new_rating': 0.18283457768819608,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.069800570942,
#   'list_pos': 17,
#   'id': 338942,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 1,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 0.0,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20190617182125602720_%EC%8A%A4%ED%83%81_20181015_foodad_fad06045-right_%EC%9C%A0%EB%B6%80%EC%B4%88%EB%B0%A501_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': True,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '16:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 화양동 15-54 1층',
#   'lat': 37.5442925139467,
#   'end': '21:20:00',
#   'slug': '경성돈가스_유부초밥',
#   'review_avg': 5.0,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200039.874877615,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 7000원',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2019-06-26T03:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 563,
#   'sms_bonus': False,
#   'franchise_id': 10,
#   'phone_downlisted': False,
#   'franchise_name': '(주)멕시카나 / 멕시카나치킨',
#   'review_image_count': 261,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '반반치킨, 치토스치킨',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712939664',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['치킨', '야식', '프랜차이즈', '1인분주문'],
#   'min_order_amount': 7000,
#   'distance': 1.2199548772390536,
#   'logo_url': '/media/franchise_logos/멕시카나_20190222_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '멕시카나-성수점',
#   'section_pos': 5,
#   'owner_reply_count': 563,
#   'one_dish': 1,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:00 - 08:59',
#   'keywords': '멕시카나-성수점 반반치킨 반반치킨 한마리치킨 치토스치킨 투마리세트 투마리세트 순살반반 순살반반 한마리치킨 후라이드치킨 한마리치킨 양념치킨 사이드／음료 콜라1.25L 한마리치킨 땡초치킨 한마리치킨 치토스치킨（콘스프맛） 주류 생맥주1000cc',
#   'new_rating': 1.3179029767965373,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.048840664326,
#   'list_pos': 18,
#   'id': 278731,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 783,
#   'relay_methods': ['email', 'relayo_relay'],
#   'section': 'contract',
#   'loyal_score': 24.0473488061087,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:00:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 성동구 성수동1가 62 1층',
#   'lat': 37.5386306669886,
#   'end': '08:59:00',
#   'slug': '멕시카나-성수점',
#   'review_avg': 4.48403575989783,
#   'discount_from': '2019-06-25T18:00:00',
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200047.944898068,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 14900원 이상',
#   'is_available_delivery': True,
#   'threshold': 11000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 86,
#   'phone_downlisted': False,
#   'franchise_name': '주식회사케이에프씨 / KFC',
#   'review_image_count': 441,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '핫크리스피치킨 1조각, 오리지널치킨 1조각',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712921999',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '피자양식', '치킨'],
#   'min_order_amount': 14900,
#   'distance': 2.3495622203305495,
#   'logo_url': '/media/franchise_logos/KFC_20181218_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': 'KFC-세종대점',
#   'section_pos': 6,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 00:30',
#   'keywords': 'KFC-세종대점 치킨메뉴 핫크리스피치킨1조각 스낵&사이드 에그타르트 치킨메뉴 오리지널치킨1조각 치킨메뉴 블랙라벨치킨1조각 스낵&사이드 비스켓 스낵&사이드 너겟4조각 스낵&사이드 후렌치후라이 스낵&사이드 코울슬로 소스류 스위트칠리소스 치킨메뉴 갓양념치킨1조각',
#   'new_rating': 1.4204090261011264,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.073569298591,
#   'list_pos': 19,
#   'id': 261386,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 1790,
#   'relay_methods': ['email', 'relayo_relay', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 32.2580367541809,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181005102053257743_%EC%A0%9C%ED%9C%B4FR_20181002_KFC_%EB%B0%B0%EA%B2%BD%ED%99%94%EB%A9%B4_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 광진구 화양동 225',
#   'lat': 37.5472166426971,
#   'end': '00:30:00',
#   'slug': 'kfc-세종대점',
#   'review_avg': 4.37486033519553,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']},
#  {'rating': 200043.054481428,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 10000원',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 101,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'representative_menus': '짜장, 볶음밥',
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712919917',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['중식', '야식', '1인분주문'],
#   'min_order_amount': 10000,
#   'distance': 1.2531824631526833,
#   'logo_url': '/media/restaurant_logos/반반탕짜면01_20131128_FoodAD_crop_200x200_j3E9t7A.jpg',
#   'except_cash': False,
#   'name': '금룡-한양대점',
#   'section_pos': 7,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:30 - 09:29',
#   'keywords': '금룡-한양대점 면류 짜장 밥류 볶음밥 면류 짬뽕 세트메뉴 세트1（탕수육＋짜장＋짬뽕） 면류 간짜장 특미 탕짜면 면류 군만두 특미 탕볶밥 세트메뉴 세트0（탕수육＋짜장2） 요리류 탕수육小',
#   'new_rating': 1.4117962080268913,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.040535908241,
#   'list_pos': 20,
#   'id': 259214,
#   'can_review': 0,
#   'estimated_delivery_time': '35~45분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 732,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 26.5608175164357,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/stock_img/%EC%A4%91%EC%8B%9D/%EC%9A%94%EB%A6%AC/%EC%8A%A4%ED%83%81_20181015_foodad_fad50957-mid_%ED%83%95%EC%88%98%EC%9C%A105_1080x640.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:30:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 성동구 행당동 19-54 한양시장 2층',
#   'lat': 37.5595191306642,
#   'end': '09:29:00',
#   'slug': '금룡-한양대점',
#   'review_avg': 4.22814207650273,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online']}]

# %%
for rest in restaurants:
    category_name = rest['categories'][0]
    print(category_name)
    category = Category.objects.get(name=category_name)
    latlng = '{lat},{lng}'.format(**rest)
    logo_url = urljoin(food_date.HOST, rest['logo_url'])
    shop = Shop(category=category, name=rest['name'], latlng=latlng, meta=rest)
    
    logo_name = os.path.basename(logo_url)
    logo_data = requests.get(logo_url).content
    shop.photo.save(logo_name, ContentFile(logo_data), save=False)
    print('{name}: {lat},{lng}, {categories}, {logo_url}'.format(**rest))
    
    shop.save()
# Out:
# 한식
# 배달삼겹돼지되지-구의점: 37.5435328805089,127.092347494384, ['한식'], /media/franchise_logos/배달삼겹돼지되지_20171122_Franchise이미지약정서_crop_200x200_isnQp2N.jpg
# 프랜차이즈
# 7번가피자-한양대점: 37.5605440999408,127.0431297, ['프랜차이즈', '피자양식'], /media/franchise_logos/7번가피자_20160205_Franchise이미지약정서_crop_200x200_PXVSv6U.jpg
# 프랜차이즈
# 파리바게뜨-뚝섬점: 37.5435828908105,127.042797084697, ['프랜차이즈', '카페디저트'], /media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg
# 프랜차이즈
# 파파존스-성수점: 37.5476884,127.0447483, ['프랜차이즈', '피자양식'], /media/franchise_logos/파파존스_20170313_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# 도미노피자-성수2호점: 37.5409968739098,127.0477029377, ['프랜차이즈', '피자양식'], /media/franchise_logos/도미노피자_20190102_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# 피자헛-성수점: 37.5477805999392,127.0570925, ['프랜차이즈', '피자양식'], /media/franchise_logos/피자헛_20170612_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# 미스터피자-성수점: 37.5374931,127.0595077, ['프랜차이즈', '피자양식'], /media/franchise_logos/미스터피자_20170417_Franchise이미지약정서_crop_200x200.JPG
# 프랜차이즈
# 배스킨라빈스-서울숲점: 37.5477308172463,127.044740217848, ['프랜차이즈', '카페디저트'], /media/franchise_logos/배스킨라빈스_20161130_Franchise이미지약정서_crop_200x200.jpg
# 한식
# 놀부부대찌개-시그마밸리점: 37.5401916,127.0550965, ['한식', '프랜차이즈'], /media/franchise_logos/놀부부대찌개_20190327_Franchise이미지약정서_crop_200x200.jpg
# 한식
# 쫄면주는삼겹본능-시그마밸리점: 37.5402710166844,127.055100697981, ['한식', '프랜차이즈'], /media/franchise_logos/쫄면주는삼겹본능_20180618_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# 박가부대-성수코오롱디지털밸리점: 37.5415546,127.0534298, ['프랜차이즈', '한식'], /media/franchise_logos/박가부대_20180830_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# 원할머니보쌈-성수점: 37.5397772,127.0545404, ['프랜차이즈', '족발보쌈'], /media/franchise_logos/원할머니보쌈02_20150716_Franchise이미지약정서_crop_200x200.jpg
# 야식
# BHC-성수점: 37.5486704,127.0491796, ['야식', '프랜차이즈', '치킨'], /media/franchise_logos/BHC_20190607_Franchise_crop_200x200.PNG
# 중식
# 동강: 37.5436425,127.0638631, ['중식', '한식', '1인분주문'], /media/restaurant_logos/짜장면01_20120524_FoodAD_crop_200x200_15.jpg
# 치킨
# BBQ-성수2점: 37.5502682,127.0482306, ['치킨', '프랜차이즈'], /media/franchise_logos/BBQ_20160928_Franchise이미지약정서_crop_200x200_AxtSe6b.jpg
# 프랜차이즈
# 버거킹-건대화양점: 37.5409386584498,127.068494238588, ['프랜차이즈', '피자양식'], /media/franchise_logos/버거킹_20170629_Franchise이미지약정서_crop_200x200.jpg
# 한식
# 경성돈가스&유부초밥: 37.5442925139467,127.069800570942, ['한식', '일식돈까스'], /media/restaurant_logos/냉모밀03_20131128_FoodAD_crop_200x200_oEG5Sxf.jpg
# 치킨
# 멕시카나-성수점: 37.5386306669886,127.048840664326, ['치킨', '야식', '프랜차이즈', '1인분주문'], /media/franchise_logos/멕시카나_20190222_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# KFC-세종대점: 37.5472166426971,127.073569298591, ['프랜차이즈', '피자양식', '치킨'], /media/franchise_logos/KFC_20181218_Franchise이미지약정서_crop_200x200.jpg
# 중식
# 금룡-한양대점: 37.5595191306642,127.040535908241, ['중식', '야식', '1인분주문'], /media/restaurant_logos/반반탕짜면01_20131128_FoodAD_crop_200x200_j3E9t7A.jpg

# %%
for shop in Shop.objects.all():
    print(shop.name)
# Out:
# BHC-화양점
# 금룡-한양대점
# 멕시카나-성수점
# 요리왕
# 眞감자탕
# 티바두마리치킨-성수화양점
# 롯데리아-답십리점
# 장모족발
# 명인찜닭&닭도리탕
# 혼술참치
# 대구안지랑곱창막창
# 바다여행
# 눈물닭발
# 멕시카나-뚝섬유원지점
# 버거킹-건대화양점(24)
# 대한닭발1979
# 홍대곱창&불닭발
# 최셰프의동파육-건대점
# 새벽4시빙수나라
# 청정활어회직판장
# BHC-화양점
# 금룡-한양대점
# 멕시카나-성수점
# 요리왕
# 眞감자탕
# 티바두마리치킨-성수화양점
# 롯데리아-답십리점
# 장모족발
# 명인찜닭&닭도리탕
# 혼술참치
# 대구안지랑곱창막창
# 바다여행
# 눈물닭발
# 멕시카나-뚝섬유원지점
# 버거킹-건대화양점(24)
# 대한닭발1979
# 홍대곱창&불닭발
# 최셰프의동파육-건대점
# 새벽4시빙수나라
# 청정활어회직판장
# 배달삼겹돼지되지-구의점
# 배달삼겹돼지되지-구의점
# 7번가피자-한양대점
# 파리바게뜨-뚝섬점
# 파파존스-성수점
# 도미노피자-성수2호점
# 피자헛-성수점
# 미스터피자-성수점
# 배스킨라빈스-서울숲점
# 놀부부대찌개-시그마밸리점
# 쫄면주는삼겹본능-시그마밸리점
# 박가부대-성수코오롱디지털밸리점
# 원할머니보쌈-성수점
# BHC-성수점
# 동강
# BBQ-성수2점
# 버거킹-건대화양점
# 경성돈가스&유부초밥
# 멕시카나-성수점
# KFC-세종대점
# 금룡-한양대점

# %%
for shop in Shop.objects.all():
    restaurant_id = shop.meta['id']
    menu_list = food.get_menu_list(restaurant_id)
    print(shop.name)
    for sub_menu_list in menu_list:
        items = sub_menu_list['items']
        for item_meta in items:
            item = Item(shop=shop, name=item_meta['name'], amount=item_meta['price'])
            
            item_image_url = item_meta.get('image', '')
            if item_image_url:
                item_image_url = urljoin(food_date.HOST, item_meta['image'])
                
                item_image_name = os.path.basename(item_image_url)
                item_image_data = requests.get(item_image_url).content
                item.photo.save(item_image_name, ContentFile(item_image_data), save=False)
                
            print('saving item : {}'.format(item.name))
            item.save()
# Out:
# BHC-화양점
# saving item : 마라칸
# saving item : 치하오
# saving item : 뿌링클
# saving item : 맛초킹（한마리）
# saving item : 소떡강정
# saving item : 해바라기후라이드치킨
# saving item : 뿌링클
# saving item : 순살뿌링클
# saving item : 후라이드 반／양념 반
# saving item : 해바라기후라이드치킨
# saving item : 맛초킹（한마리）
# saving item : 달콤바삭치즈볼
# saving item : 마라칸
# saving item : 해바라기핫후라이드치킨
# saving item : 뿌링치즈볼
# saving item : 뿌링클다리¸
# saving item : 마라칸
# saving item : 순살마라칸
# saving item : 마라칸다리
# saving item : 마라칸날개
# saving item : 마라칸（제）
# saving item : 순살마라칸（제）
# saving item : 마라칸다리（제）
# saving item : 마라칸날개（제）
# saving item : 소떡강정
# saving item : 마라칸＋뿌링소떡
# saving item : 마라칸＋빨간소떡
# saving item : 마라칸＋뿌링치즈볼
# saving item : 마라칸＋치즈볼
# saving item : 마라칸＋뿌링소떡（제）
# saving item : 마라칸＋빨간소떡（제）
# saving item : 마라칸＋뿌링치즈볼（제）
# saving item : 마라칸＋치즈볼（제）
# saving item : 치하오＋뿌링소떡
# saving item : 치하오＋빨간소떡
# saving item : 치하오＋뿌링감자
# saving item : 치하오＋뿌링치즈볼
# saving item : 뿌링클＋뿌링소떡
# saving item : 뿌링클＋빨간소떡
# saving item : 뿌링클＋뿌링감자
# saving item : 뿌링클＋뿌링치즈볼
# saving item : 맛초킹＋뿌링소떡
# saving item : 맛초킹＋빨간소떡
# saving item : 맛초킹＋뿌링감자
# saving item : 맛초킹＋뿌링치즈볼
# saving item : 후라이드＋뿌링소떡
# saving item : 후라이드＋빨간소떡
# saving item : 후라이드＋뿌링감자
# saving item : 후라이드＋뿌링치즈볼
# saving item : 양념＋뿌링소떡
# saving item : 양념＋빨간소떡
# saving item : 양념＋뿌링감자
# saving item : 양념＋뿌링치즈볼
# saving item : 치하오＋뿌링감자（제）
# saving item : 뿌링클＋뿌링감자（제）
# saving item : 맛초킹＋뿌링감자（제）
# saving item : 후라이드＋뿌링감자（제）
# saving item : 양념＋뿌링감자（제）
# saving item : 뿌링클＋치즈볼
# saving item : 맛초킹＋치즈볼
# saving item : 치하오＋치즈볼
# saving item : 후라이드＋치즈볼
# saving item : 양념＋치즈볼
# saving item : 맛초킹＋뿌링미니콜팝
# saving item : 치하오＋뿌링미니콜팝
# saving item : 후라이드＋뿌링미니콜팝
# saving item : 양념＋뿌링미니콜팝
# saving item : 치하오
# saving item : 치하오날개
# saving item : 치하오다리
# saving item : 치하오순살
# saving item : 소이바베큐
# saving item : 순살소이바베큐
# saving item : 핫소이바베큐
# saving item : 순살핫소이바베큐
# saving item : 갈비레오
# saving item : 핫갈비레오
# saving item : 붐바스틱
# saving item : 치레카
# saving item : 순살치레카
# saving item : 치레카날개¸
# saving item : 치레카다리¸
# saving item : 커리퀸
# saving item : 순살커리퀸
# saving item : 커리퀸날개¸
# saving item : 커리퀸다리¸
# saving item : 맵스터
# saving item : 순살맵스터
# saving item : 맵스터날개¸
# saving item : 맵스터다리¸
# saving item : 맛초킹（한마리）
# saving item : 순살맛초킹
# saving item : 맛초킹날개¸
# saving item : 맛초킹다리¸
# saving item : 뿌링클
# saving item : 뿌링클날개¸
# saving item : 뿌링클다리¸
# saving item : 뿌링클HOT
# saving item : 순살뿌링클
# saving item : 순살뿌링클HOT
# saving item : 바삭클
# saving item : 순살바삭클
# saving item : 해바라기후라이드치킨
# saving item : 후라이드 반／양념 반
# saving item : 해바라기핫후라이드치킨
# saving item : 해바라기닭다리후라이드치킨
# saving item : 닭날개후라이드
# saving item : 양념치킨
# saving item : 매운맛양념치킨
# saving item : 간장골드한마리
# saving item : 간장골드날개¸
# saving item : 간장골드다리¸
# saving item : 콜팝치킨
# saving item : 미니콜팝
# saving item : 왕콜팝
# saving item : 빅콜팝
# saving item : 뿌링콜팝
# saving item : 뿌링미니콜팝
# saving item : 뿌링왕콜팝
# saving item : 뿌링빅콜팝
# saving item : 뿌링소떡
# saving item : 빨간소떡
# saving item : 뿌링감자
# saving item : 뿌링치즈볼
# saving item : 달콤바삭치즈볼
# saving item : 케이준프라이
# saving item : 뿌링치즈스틱
# saving item : 콜라1.25L¸
# saving item : 사이다1.25L¸
# saving item : 콜라500ml
# saving item : 치킨무
# saving item : 양념소스
# saving item : 머스타드소스
# saving item : 커리딥소스
# saving item : 뿌링뿌링소스
# 금룡-한양대점
# saving item : 짜장
# saving item : 탕수육 小
# saving item : 라조기
# saving item : 유산슬
# saving item : 홍합짬뽕
# saving item : 삼품냉채
# saving item : 짜장
# saving item : 볶음밥
# saving item : 짬뽕
# saving item : 탕짜면
# saving item : 세트1（탕수육＋짜장＋짬뽕）
# saving item : 간짜장
# saving item : 탕볶밥
# saving item : 탕짬면
# saving item : 세트0（탕수육＋짜장2）
# saving item : 군만두
# saving item : 짜장
# saving item : 짬뽕
# saving item : 울면
# saving item : 우동
# saving item : 간짜장
# saving item : 유니짜장
# saving item : 삼선간짜장
# saving item : 삼선짬뽕
# saving item : 삼선우동
# saving item : 삼선울면
# saving item : 기스면
# saving item : 매운짬뽕
# saving item : 굴짬뽕
# saving item : 고추짬뽕
# saving item : 홍합짬뽕
# saving item : 떡볶이 쟁반짜장
# saving item : 떡볶이 볶음짬뽕
# saving item : 누룽지탕
# saving item : 군만두
# saving item : 볶음밥
# saving item : 짬뽕밥
# saving item : 짜장밥
# saving item : 김치볶음밥
# saving item : 잡채밥
# saving item : 새우볶음밥
# saving item : 삼선볶음밥
# saving item : 고추잡채밥
# saving item : 마파두부밥
# saving item : 금룡정식
# saving item : 유산슬밥
# saving item : 잡탕밥
# saving item : 물만두
# saving item : 탕수육 小
# saving item : 탕수육 中
# saving item : 탕수육 大
# saving item : 사천탕수육
# saving item : 라조기
# saving item : 라조육
# saving item : 깐풍기
# saving item : 깐풍육
# saving item : 새우와두부
# saving item : 자연송이와죽순
# saving item : 동고버섯과죽순
# saving item : 고추잡채
# saving item : 유산슬
# saving item : 팔보채
# saving item : 잡탕
# saving item : 전가복
# saving item : 샥스핀
# saving item : 사품냉채
# saving item : 삼품냉채
# saving item : 이품냉채
# saving item : 해파리냉채
# saving item : 해삼과자연송이
# saving item : 해삼탕
# saving item : 라조새우
# saving item : 깐쇼새우
# saving item : 새우와자연송이
# saving item : 소고기탕수육
# saving item : 소고기튀김
# saving item : 술국
# saving item : 당면잡채
# saving item : 마파두부
# saving item : 양장피
# saving item : 난자완스
# saving item : 쟁반짜장 1人
# saving item : 쟁반짜장 2人
# saving item : 돈까스정식
# saving item : 탕짜면
# saving item : 탕짬면
# saving item : 탕볶밥
# saving item : 세트0（탕수육＋짜장2）
# saving item : 세트1（탕수육＋짜장＋짬뽕）
# saving item : 세트2（깐풍육＋짜장＋짬뽕）
# saving item : 세트3（깐풍기＋짜장＋짬뽕）
# saving item : 세트4（탕수육＋쟁반짜장＋군만두 or 물만두）
# saving item : 세트5（양장피＋쟁반짜장＋군만두 or 물만두）
# saving item : 세트6（깐풍기＋쟁반짜장＋군만두 or 물만두）
# saving item : 세트7（팔보채＋쟁반짜장＋군만두 or 물만두）
# saving item : 부추잡채
# saving item : 물냉면
# saving item : 비빔냉면
# saving item : 콩국수
# 멕시카나-성수점
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 땡초치킨
# saving item : 후라이드치킨
# saving item : Mr.김치킨
# saving item : 눈꽃치즈치킨
# saving item : 반반치킨
# saving item : 치토스치킨
# saving item : 투마리세트
# saving item : 순살반반
# saving item : 양념치킨
# saving item : 후라이드치킨
# saving item : 치토스치킨（콘스프맛）
# saving item : 순살치토스치킨
# saving item : 순살세트
# saving item : 땡초치킨
# saving item : Mr.김치킨
# saving item : 강정치킨（뼈）
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 오징어짬뽕치킨
# saving item : 간장땡초치킨
# saving item : 간장마늘치킨
# saving item : 골드치킨（간장）
# saving item : 눈꽃치즈치킨
# saving item : 땡초치킨
# saving item : 마늘치킨
# saving item : 매운양념치킨
# saving item : 양념치킨
# saving item : 허니벌꿀치킨
# saving item : 후라이드치킨
# saving item : 순살Mr.김치킨
# saving item : 순살강정치킨
# saving item : 순살오징어짬뽕치킨
# saving item : 순살골드치킨（간장）
# saving item : 순살눈꽃치즈치킨
# saving item : 순살땡초치킨
# saving item : 순살마늘치킨
# saving item : 순살매운양념치킨
# saving item : 순살양념치킨
# saving item : 순살허니벌꿀치킨
# saving item : 순살후라이드치킨
# saving item : 순살치토스치킨
# saving item : 순살치토스치킨（콘스프맛）
# saving item : 반반치킨
# saving item : 순살반반
# saving item : 투마리세트
# saving item : 순살세트
# saving item : 달콤한윙
# saving item : 달콤한핀
# saving item : 매콤한윙
# saving item : 멕시듀오（다리＋날개）
# saving item : 멕시듀오（간장）
# saving item : 멕시듀오（간장＋양념）
# saving item : 멕시듀오（땡초）
# saving item : 멕시듀오（양념）
# saving item : 멕시듀오（허니벌꿀）
# saving item : 멕시듀오（후라이드＋간장）
# saving item : 멕시듀오（후라이드＋양념）
# saving item : 간장소스윙
# saving item : 멕시윙（간장＋양념）
# saving item : 멕시윙（눈꽃치즈）
# saving item : 멕시윙（땡초）
# saving item : 멕시윙（후라이드）
# saving item : 멕시윙（양념）
# saving item : 멕시핀（후라이드）
# saving item : 멕시핀（간장）
# saving item : 멕시핀（눈꽃치즈）
# saving item : 멕시핀（땡초）
# saving item : 멕시핀（양념）
# saving item : 멕시윙반반（후라이드＋양념）
# saving item : 멕시핀반반（후라이드＋양념）
# saving item : 한입튀김밥
# saving item : 고추튀김
# saving item : 머스터드 소스 추가
# saving item : 멕시감자
# saving item : 모래집땡초大
# saving item : 모래집후라이드大
# saving item : 무추가
# saving item : 사이다 1.25L
# saving item : 새우링
# saving item : 양념소스 추가
# saving item : 엔젤코코소스 추가
# saving item : 체다치즈볼
# saving item : 콜라 1.25L
# saving item : 콜라 500mL
# saving item : 햇반세트
# saving item : 땡초모래집후라이드
# 요리왕
# saving item : 짬뽕
# saving item : 우동
# saving item : 간짜장
# saving item : 삼선짬뽕
# saving item : 삼선울면
# saving item : 삼선우동
# saving item : 짜장
# saving item : 군만두
# saving item : 짬뽕
# saving item : 탕짜면
# saving item : 간짜장
# saving item : B 세트. 탕수육＋짜장＋짬뽕
# saving item : 0-1 세트. 탕수육＋짜장 or 짬뽕
# saving item : 탕볶밥
# saving item : 탕수육정식（탕수육＋볶음밥＋짜장＋짬뽕국물）
# saving item : 탕수육
# saving item : 잡채밥
# saving item : 탕수육정식（탕수육＋볶음밥＋짜장＋짬뽕국물）
# saving item : 깐쇼새우정식（깐쇼새우＋볶음밥＋짜장＋짬뽕국물）
# saving item : 팔보채정식（팔보채＋볶음밥＋짜장＋짬뽕국물）
# saving item : 볶음밥
# saving item : 짬뽕밥
# saving item : 짜장밥
# saving item : 김치볶음밥
# saving item : 오므라이스
# saving item : 제육덮밥
# saving item : 마파두부밥
# saving item : 오징어덮밥
# saving item : 삼선볶음밥
# saving item : 새우볶음밥
# saving item : 송이밥
# saving item : 고추덮밥
# saving item : 요리왕특밥
# saving item : 삼선짬뽕밥
# saving item : 잡탕밥
# saving item : 류산슬밥
# saving item : 고추짬뽕밥
# saving item : 짜장
# saving item : 짬뽕
# saving item : 우동
# saving item : 울면
# saving item : 간짜장
# saving item : 삼선간짜장
# saving item : 기스면
# saving item : 삼선짬뽕
# saving item : 삼선쟁반짜장
# saving item : 해물볶음짬뽕
# saving item : 고추짬뽕
# saving item : 삼선울면
# saving item : 삼선우동
# saving item : 불타는 쟁반짜장
# saving item : 불타는 볶음짬뽕
# saving item : 고기짬뽕
# saving item : 차돌짬뽕
# saving item : 탕수육
# saving item : 사천탕수육
# saving item : 김치감자탕
# saving item : 해물탕
# saving item : 꽃게탕
# saving item : 돼지갈비찜 小（2人）
# saving item : 돼지갈비찜 中（3人）
# saving item : 돼지갈비찜 大（4人）
# saving item : 소갈비찜 小（2人）
# saving item : 소갈비찜 中（3人）
# saving item : 소갈비찜 大（4人）
# saving item : 묵은지 돼지갈비찜 小
# saving item : 묵은지 돼지갈비찜 中
# saving item : 묵은지 돼지갈비찜 大
# saving item : 삼계탕（2人）
# saving item : 공기밥
# saving item : 주먹＋계란찜
# saving item : 콜라 500mL
# saving item : 사이다 500mL
# saving item : 생수 500mL
# saving item : 콜라 1.25L
# saving item : 사이다 1.5L
# saving item : 생수 1.5L
# 티바두마리치킨-성수화양점
# saving item : 마늘간장＋후라이드
# saving item : 양념치킨＋후라이드
# saving item : 땡초갈릭＋후라이드
# saving item : 수제아삭킹새우（10마리）＋후라이드
# saving item : 후라이드＋후라이드
# saving item : 양념치킨＋마늘간장
# saving item : 양념치킨＋후라이드
# saving item : 양념치킨＋마늘간장
# saving item : 마늘간장＋후라이드
# saving item : 마늘간장
# saving item : 후라이드
# saving item : 양념치킨
# saving item : 땡초갈릭＋후라이드
# saving item : 치즈스노우퀸＋후라이드
# saving item : 커리양념＋후라이드
# saving item : 후라이드＋후라이드
# saving item : 후라이드＋후라이드
# saving item : 양념치킨＋후라이드
# saving item : 마늘간장＋후라이드
# saving item : 양념치킨＋마늘간장
# saving item : 땡초갈릭＋후라이드
# saving item : 커리양념＋후라이드
# saving item : 치즈스노우퀸＋후라이드
# saving item : 후라이드
# saving item : 양념치킨
# saving item : 마늘간장
# saving item : 땡초갈릭
# saving item : 커리양념
# saving item : 치즈스노우퀸
# saving item : 삼삼세트
# saving item : 수제아삭킹새우（5마리）
# saving item : 수제아삭킹새우（10마리）
# saving item : 수제아삭킹새우（10마리）＋후라이드
# saving item : 국물떡볶이（소）
# saving item : 치즈스틱
# saving item : 황금감자
# saving item : JMT찹쌀치즈봉
# saving item : 콜라 500ml
# saving item : 콜라 1.25L
# saving item : 사이다 1.25L
# saving item : 치킨무
# saving item : 티바양념소스
# saving item : 매운양념소스
# saving item : 크리미양파소스＋생양파채
# saving item : 파채
# saving item : 땡초갈릭소스
# saving item : 떡사리
# 롯데리아-답십리점
# saving item : 와규에디션Ⅱ세트
# saving item : DoubleX2세트
# saving item : NEW홈패밀리팩
# saving item : NEW홈더블팩
# saving item : 와규에디션Ⅱ
# saving item : 한우불고기버거
# saving item : 핫크리스피버거세트
# saving item : DoubleX2세트
# saving item : 새우버거세트
# saving item : 불고기버거세트
# saving item : T-REX버거 세트
# saving item : 불고기버거
# saving item : 모짜렐라인더 버거-베이컨 세트
# saving item : 새우버거
# saving item : 치킨 1조각
# saving item : T-REX버거
# saving item : 와규에디션Ⅱ
# saving item : DoubleX2버거
# saving item : 더블치킨버거
# saving item : 더블클래식치즈버거
# saving item : T-REX버거
# saving item : 비프바베큐버거
# saving item : 모짜렐라인더버거-해쉬
# saving item : 모짜렐라인더버거-더블
# saving item : 모짜렐라인더버거-베이컨
# saving item : AZ오리지널
# saving item : 데리버거
# saving item : 치킨버거
# saving item : 불고기버거
# saving item : 새우버거
# saving item : 원조빅불
# saving item : 한우불고기버거
# saving item : 핫크리스피버거
# saving item : 클래식치즈버거
# saving item : 와규에디션Ⅱ세트
# saving item : DoubleX2세트
# saving item : 더블치킨세트
# saving item : 더블클래식치즈세트
# saving item : T-REX버거 세트
# saving item : 모짜렐라인더 버거-베이컨 세트
# saving item : 모짜렐라인더 버거-해쉬 세트
# saving item : 모짜렐라인더 버거-더블 세트
# saving item : AZ오리지널세트
# saving item : 데리세트
# saving item : 치킨버거세트
# saving item : 불고기버거세트
# saving item : 새우버거세트
# saving item : 원조빅불세트
# saving item : 한우불고기세트
# saving item : 핫크리스피버거세트
# saving item : 클래식치즈버거 세트
# saving item : 해쉬브라운
# saving item : 양념감자
# saving item : 오징어링
# saving item : 치즈스틱
# saving item : 롱치즈스틱
# saving item : 콘샐러드
# saving item : 포테이토
# saving item : 포테이토（L）
# saving item : 베리베리 팥빙수
# saving item : 오렌지（PET-400ml）
# saving item : 레몬에이드
# saving item : 사이다（R）
# saving item : 아메리카노
# saving item : ICE아메
# saving item : ICE아메라지
# saving item : 아이스 카페라떼
# saving item : 카페라떼
# saving item : 콜라（R）
# saving item : 콜라（L）
# saving item : 콜라1.25L（PET）
# saving item : 사이다（L）
# saving item : 사이다1.25L（PET）
# saving item : 순살치킨 풀팩
# saving item : 순살치킨 하프팩
# saving item : 치킨 1조각
# saving item : 치킨풀팩-콘샐러드
# saving item : 치킨하프팩-콘샐러드
# saving item : 치킨풀팩-포테이토
# saving item : 치킨하프팩-포테이토
# saving item : 치킨패밀리팩-콘샐러드
# saving item : 치킨패밀리팩-포테이토
# saving item : 치킨휠레 2조각
# saving item : 치킨휠레 4조각
# saving item : NEW홈더블팩
# saving item : NEW홈패밀리팩
# saving item : 데리야끼소스
# saving item : 머스타드소스
# saving item : 핫소스
# saving item : 휠레소스_허니머스타드
# saving item : 휠레소스_스위트앤샤워
# saving item : 시즈닝_치즈맛
# saving item : 시즈닝_칠리맛
# saving item : 시즈닝_오니언맛
# 장모족발
# saving item : 쟁반막국수
# saving item : 모래집구이
# saving item : 왕새우튀김
# saving item : 고구마치즈스틱
# saving item : 콜라 500mL
# saving item : 사이다 500mL
# saving item : 족발 앞다리 大＋쟁반막국수＋콜라 500mL
# saving item : （족발반＋보쌈반）＋쟁반막국수＋콜라
# saving item : 족발 뒷다리 中＋쟁반막국수＋콜라 500mL
# saving item : 꽃게장 보쌈 中＋쟁반막국수＋콜라 500mL
# saving item : 꽃게장 보쌈 大＋쟁반막국수＋콜라 500mL
# saving item : （족발반＋불족발반）＋쟁반막국수＋콜라
# saving item : 핫바베큐족＋쟁반막국수＋콜라 500mL
# saving item : （족발반＋핫바베큐반）＋쟁반막국수＋콜라
# saving item : 갈릭족＋쟁반막국수＋콜라 500mL
# saving item : 모래집구이
# saving item : 족발 뒷다리 中＋쟁반막국수＋콜라 500mL
# saving item : 족발 앞다리 大＋쟁반막국수＋콜라 500mL
# saving item : 핫바베큐족＋쟁반막국수＋콜라 500mL
# saving item : 오븐족＋쟁반막국수＋콜라 500mL
# saving item : 갈릭족＋쟁반막국수＋콜라 500mL
# saving item : 꽃게장 보쌈 中＋쟁반막국수＋콜라 500mL
# saving item : 꽃게장 보쌈 大＋쟁반막국수＋콜라 500mL
# saving item : （족발반＋보쌈반）＋쟁반막국수＋콜라
# saving item : （족발반＋불족발반）＋쟁반막국수＋콜라
# saving item : （족발반＋핫바베큐반）＋쟁반막국수＋콜라
# saving item : （족발반＋갈릭족반）＋쟁반막국수＋콜라
# saving item : 쟁반막국수
# saving item : 모래집구이
# saving item : 왕새우튀김
# saving item : 고구마치즈스틱
# saving item : 콜라 500mL
# saving item : 사이다 500mL
# 명인찜닭&닭도리탕
# saving item : 안동찜닭 大
# saving item : 해물찜닭 小
# saving item : 닭도리탕 小
# saving item : 삼계탕 （2마리）
# saving item : 닭도리탕 中
# saving item : 닭도리탕 大
# saving item : 닭도리탕 小
# saving item : 안동찜닭 小
# saving item : 뼈없는찜닭 小
# saving item : 닭도리탕 中
# saving item : 안동찜닭 中
# saving item : 뼈없는찜닭 中
# saving item : 뼈없는 닭도리탕 小
# saving item : 삼계탕 （2마리）
# saving item : 안동찜닭 大
# saving item : 뼈없는 닭도리탕 中
# saving item : 닭도리탕 小
# saving item : 닭도리탕 中
# saving item : 닭도리탕 大
# saving item : 뼈없는 닭도리탕 小
# saving item : 뼈없는 닭도리탕 中
# saving item : 뼈없는 닭도리탕 大
# saving item : 안동찜닭 小
# saving item : 안동찜닭 中
# saving item : 안동찜닭 大
# saving item : 뼈없는찜닭 小
# saving item : 뼈없는찜닭 中
# saving item : 뼈없는찜닭 大
# saving item : 고구마찜닭 小
# saving item : 고구마찜닭 中
# saving item : 고구마찜닭 大
# saving item : 김치떡도리탕 小
# saving item : 김치떡도리탕 中
# saving item : 김치떡도리탕 大
# saving item : 해물찜닭 小
# saving item : 해물찜닭 中
# saving item : 해물찜닭 大
# saving item : 불찜닭 小
# saving item : 불찜닭 中
# saving item : 불찜닭 大
# saving item : 치즈닭도리탕 小
# saving item : 치즈닭도리탕 中
# saving item : 치즈닭도리탕 大
# saving item : 삼계탕 （2마리）
# saving item : 공기밥
# saving item : 주먹＋계란찜
# saving item : 당면 추가
# saving item : 떡사리 추가
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 스프라이트 500mL
# saving item : 스프라이트 1.25L
# 혼술참치
# saving item : 미
# saving item : 선
# saving item : 진
# saving item : 진
# saving item : 선
# saving item : 미
# 대구안지랑곱창막창
# saving item : 직화양념곱창400g
# saving item : 직화양념막창400g
# saving item : 훈제막창400g
# saving item : 곱창전골600g
# saving item : 주먹밥
# saving item : 날치알주먹밥
# saving item : 곱창세트（직화양념곱창＋세트서비스）
# saving item : 반반（양념곱창200g＋훈제막창200g）
# saving item : 막창세트（직화양념막창＋세트서비스）
# saving item : 직화양념곱창400g
# saving item : 반반（양념막창200g＋훈제막창200g）
# saving item : 반반（양념곱창200g＋양념막창200g）
# saving item : 곱창전골600g
# saving item : 염통200g
# saving item : 훈제막창400g
# saving item : 치곱세트（치즈직화양념곱창＋세트서비스）
# saving item : 치즈직화양념곱창400g
# saving item : 직화양념곱창400g
# saving item : 데리야끼막창400g
# saving item : 직화양념막창400g
# saving item : 훈제막창400g
# saving item : 곱창전골600g
# saving item : 반반（양념막창200g＋훈제막창200g）
# saving item : 반반（양념곱창200g＋양념막창200g）
# saving item : 반반（양념곱창200g＋훈제막창200g）
# saving item : 안지랑세트（직화양념곱창＋곱창전골 600g＋세트서비스）
# saving item : 치곱세트（치즈직화양념곱창＋세트서비스）
# saving item : 곱창세트（직화양념곱창＋세트서비스）
# saving item : 막창세트（직화양념막창＋세트서비스）
# saving item : 오막세트400g（데리야끼 오븐막창＋세트서비스）
# saving item : 고불세트（고추장불고기＋세트서비스）
# saving item : 염통200g
# saving item : 음료수
# saving item : 주먹밥
# saving item : 날치알주먹밥
# saving item : 공기밥
# 바다여행
# saving item : 광어
# saving item : 우럭
# saving item : 세트특선（광어＋우럭）
# saving item : 해산물모둠（전복＋해삼＋멍게＋개불＋가리비 또는 석화＋참소라＋새우＋기타계절해산물＋낙지or낙지호롱＋스끼다시5종＋초밥）
# saving item : 개불
# saving item : 멍게
# saving item : 세트특선（광어＋우럭）
# saving item : 세트특선（광어＋우럭＋계절활어＋연어）
# saving item : 세트특선（광어＋연어）
# saving item : 우럭
# saving item : 활어회물회
# saving item : 연어초밥10pcs
# saving item : 광어
# saving item : 해산물모둠（전복＋해삼＋멍게＋개불＋가리비 또는 석화＋참소라＋새우＋기타계절해산물＋낙지or낙지호롱＋스끼다시5종＋초밥）
# saving item : 산낙지
# saving item : 세트특선（우럭＋연어）
# saving item : 모둠회（광어＋우럭＋계절활어＋연어）
# saving item : 광어
# saving item : 우럭
# saving item : 생연어
# saving item : 숭어
# saving item : 전복치（미역치）
# saving item : 놀래미
# saving item : 도미
# saving item : 농어
# saving item : 도다리세꼬시
# saving item : 아나고세꼬시
# saving item : 줄돔세꼬시
# saving item : 대광어
# saving item : 대도미（1.5kg）
# saving item : 대농어（1.5kg）
# saving item : 세트특선（광어＋우럭＋계절활어＋연어）
# saving item : 세트특선（광어＋우럭）
# saving item : 세트특선（광어＋연어）
# saving item : 세트특선（우럭＋연어）
# saving item : 세트특선（광어＋숭어）
# saving item : 세트특선（우럭＋숭어）
# saving item : 세트특선（광어＋우럭＋숭어）
# saving item : 세트특선（광어＋우럭＋아나고）
# saving item : 세트특선（광어＋우럭＋전복치）
# saving item : 세트특선（광어＋우럭＋새우튀김）
# saving item : 세트특선（광어＋우럭＋왕홍새우구이）
# saving item : 세트특선（광어＋우럭＋돌멍게）
# saving item : 세트특선（광어＋우럭＋비단멍게）
# saving item : 세트특선（광어＋우럭＋해산물모둠）
# saving item : 세트특선（광어＋우럭＋산낙지＋해산물모둠）
# saving item : 세트특선（광어＋우럭＋활랍스터찜500g）
# saving item : 뼈찜
# saving item : 부대전골
# saving item : 김치전골
# saving item : 만두전골
# saving item : 곱창전골
# saving item : 낙곱전골
# saving item : 불낙전골
# saving item : 불고기전골
# saving item : 쿨피스
# saving item : 콜라 小
# saving item : 사이다 小
# saving item : 콜라 大
# saving item : 사이다 大
# saving item : 생수
# saving item : 참치주먹밥
# saving item : 멸치주먹밥
# saving item : 날치알주먹밥
# saving item : 게란찜
# saving item : 공기밥
# 멕시카나-뚝섬유원지점
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 땡초치킨
# saving item : 후라이드치킨
# saving item : Mr.김치킨
# saving item : 눈꽃치즈치킨
# saving item : 반반치킨
# saving item : 투마리세트
# saving item : 후라이드치킨
# saving item : 순살반반
# saving item : 치토스치킨
# saving item : 치토스치킨（콘스프맛）
# saving item : 양념치킨
# saving item : 순살세트
# saving item : 순살치토스치킨
# saving item : 땡초치킨
# saving item : Mr.김치킨
# saving item : 강정치킨（뼈）
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 오징어짬뽕치킨
# saving item : 골드치킨（간장）
# saving item : 눈꽃치즈치킨
# saving item : 땡초치킨
# saving item : 마늘치킨
# saving item : 매운양념치킨
# saving item : 양념치킨
# saving item : 허니벌꿀치킨
# saving item : 후라이드치킨
# saving item : 순살Mr.김치킨
# saving item : 순살강정치킨
# saving item : 순살오징어짬뽕치킨
# saving item : 순살골드치킨（간장）
# saving item : 순살눈꽃치즈치킨
# saving item : 순살땡초치킨
# saving item : 순살마늘치킨
# saving item : 순살매운양념치킨
# saving item : 순살양념치킨
# saving item : 순살허니벌꿀치킨
# saving item : 순살후라이드치킨
# saving item : 순살치토스치킨
# saving item : 순살치토스치킨（콘스프맛）
# saving item : 반반치킨
# saving item : 순살반반
# saving item : 투마리세트
# saving item : 순살세트
# saving item : 달콤한윙
# saving item : 달콤한핀
# saving item : 매콤한윙
# saving item : 멕시듀오（다리＋날개）
# saving item : 간장소스윙
# saving item : 멕시윙（눈꽃치즈）
# saving item : 멕시윙（땡초）
# saving item : 멕시윙（후라이드）
# saving item : 멕시윙（양념）
# saving item : 멕시핀（후라이드）
# saving item : 멕시핀（간장）
# saving item : 멕시핀（눈꽃치즈）
# saving item : 멕시핀（땡초）
# saving item : 멕시핀（양념）
# saving item : 멕시윙반반（후라이드＋양념）
# saving item : 멕시핀반반（후라이드＋양념）
# saving item : 한입튀김밥
# saving item : 고추튀김
# saving item : 눈꽃치즈감자
# saving item : 닭치고닭발（무뼈닭발）小
# saving item : 땡초소스 추가
# saving item : 머스터드 소스 추가
# saving item : 멕시감자
# saving item : 모래집땡초大
# saving item : 모래집후라이드大
# saving item : 무추가
# saving item : 사이다 1.25L
# saving item : 새우링
# saving item : 양념소스 추가
# saving item : 체다치즈볼
# saving item : 콜라 1.25L
# saving item : 콜라 500mL
# saving item : 닭치고닭발（무뼈닭발）
# saving item : 땡초모래집후라이드
# saving item : 마늘똥집
# saving item : 매운무뼈닭발
# saving item : 블루베리설화빙수
# saving item : 녹차설화빙수
# saving item : 밀크티설화빙수
# saving item : 눈꽃바나나뉴텔라빙수
# saving item : 카라멜설화빙수
# saving item : 망고설화빙수
# saving item : 블루베리설화빙수
# saving item : 자몽설화빙수
# saving item : 바나나설화빙수
# saving item : 카라멜설화빙수
# saving item : 초코설화빙수
# saving item : 밀크티설화빙수
# saving item : 녹차설화빙수
# saving item : 옛날팥빙수
# saving item : 딸기빙수
# saving item : 바나나빙수
# saving item : 블루베리가당빙수
# saving item : 자몽모히또빙수
# saving item : 바나나모히또빙수
# saving item : 딸기모히또빙수
# saving item : 라임모히또빙수
# saving item : 눈꽃생딸기빙수
# saving item : 눈꽃밤빙수
# saving item : 눈꽃인절미견과류빙수
# saving item : 눈꽃생키위빙수
# saving item : 눈꽃초코카라멜빙수
# saving item : 눈꽃아보카도빙수
# saving item : 눈꽃파인애플빙수
# saving item : 눈꽃바나나뉴텔라빙수
# saving item : 눈꽃딸기뉴텔라빙수
# saving item : 젤라또 아이스크림（4가지맛）
# saving item : 망고아이스크림
# saving item : 블루베리아이스크림
# saving item : 딸기아이스크림
# saving item : 바나나아이스크림
# saving item : 키위아이스크림
# saving item : 초코아이스크림
# saving item : 체리베리아이스크림
# saving item : 호박아이스크림
# saving item : 녹차아이스크림
# saving item : 자몽아이스크림
# saving item : 파인애플 아이스크림
# saving item : 요거트 아이스크림
# saving item : 밀크티
# saving item : 녹차라떼
# saving item : 커피프라페
# saving item : 자몽프라페
# 청정활어회직판장
# saving item : 광어
# saving item : 우럭
# saving item : 광어＋우럭
# saving item : 멍게
# saving item : 개불
# saving item : 해삼
# saving item : 광어＋연어
# saving item : 광어
# saving item : 광어＋우럭
# saving item : 초밥 1인분（10pcs）
# saving item : 우럭
# saving item : 연어회
# saving item : 모듬회
# saving item : 광어＋우럭＋연어
# saving item : 도다리 세꼬시
# saving item : 낙지
# saving item : 모듬회
# saving item : 광어
# saving item : 우럭
# saving item : 광어＋우럭
# saving item : 연어회
# saving item : 광어＋연어
# saving item : 광어＋우럭＋연어
# saving item : 도다리
# saving item : 도미
# saving item : 농어
# saving item : 전어
# saving item : 광어 세꼬시
# saving item : 도다리 세꼬시
# saving item : 멍게
# saving item : 낙지
# saving item : 개불
# saving item : 해삼
# saving item : 오징어회
# saving item : 오징어통찜
# saving item : 초밥 1인분（10pcs）
# saving item : 연어초밥 1인분（10pcs）
# saving item : 회덮밥
# saving item : 매운탕
# saving item : 통우럭탕
# BHC-화양점
# saving item : 마라칸
# saving item : 치하오
# saving item : 뿌링클
# saving item : 맛초킹（한마리）
# saving item : 소떡강정
# saving item : 해바라기후라이드치킨
# saving item : 뿌링클
# saving item : 순살뿌링클
# saving item : 후라이드 반／양념 반
# saving item : 해바라기후라이드치킨
# saving item : 맛초킹（한마리）
# saving item : 달콤바삭치즈볼
# saving item : 마라칸
# saving item : 해바라기핫후라이드치킨
# saving item : 뿌링치즈볼
# saving item : 뿌링클다리¸
# saving item : 마라칸
# saving item : 순살마라칸
# saving item : 마라칸다리
# saving item : 마라칸날개
# saving item : 마라칸（제）
# saving item : 순살마라칸（제）
# saving item : 마라칸다리（제）
# saving item : 마라칸날개（제）
# saving item : 소떡강정
# saving item : 마라칸＋뿌링소떡
# saving item : 마라칸＋빨간소떡
# saving item : 마라칸＋뿌링치즈볼
# saving item : 마라칸＋치즈볼
# saving item : 마라칸＋뿌링소떡（제）
# saving item : 마라칸＋빨간소떡（제）
# saving item : 마라칸＋뿌링치즈볼（제）
# saving item : 마라칸＋치즈볼（제）
# saving item : 치하오＋뿌링소떡
# saving item : 치하오＋빨간소떡
# saving item : 치하오＋뿌링감자
# saving item : 치하오＋뿌링치즈볼
# saving item : 뿌링클＋뿌링소떡
# saving item : 뿌링클＋빨간소떡
# saving item : 뿌링클＋뿌링감자
# saving item : 뿌링클＋뿌링치즈볼
# saving item : 맛초킹＋뿌링소떡
# saving item : 맛초킹＋빨간소떡
# saving item : 맛초킹＋뿌링감자
# saving item : 맛초킹＋뿌링치즈볼
# saving item : 후라이드＋뿌링소떡
# saving item : 후라이드＋빨간소떡
# saving item : 후라이드＋뿌링감자
# saving item : 후라이드＋뿌링치즈볼
# saving item : 양념＋뿌링소떡
# saving item : 양념＋빨간소떡
# saving item : 양념＋뿌링감자
# saving item : 양념＋뿌링치즈볼
# saving item : 치하오＋뿌링감자（제）
# saving item : 뿌링클＋뿌링감자（제）
# saving item : 맛초킹＋뿌링감자（제）
# saving item : 후라이드＋뿌링감자（제）
# saving item : 양념＋뿌링감자（제）
# saving item : 뿌링클＋치즈볼
# saving item : 맛초킹＋치즈볼
# saving item : 치하오＋치즈볼
# saving item : 후라이드＋치즈볼
# saving item : 양념＋치즈볼
# saving item : 맛초킹＋뿌링미니콜팝
# saving item : 치하오＋뿌링미니콜팝
# saving item : 후라이드＋뿌링미니콜팝
# saving item : 양념＋뿌링미니콜팝
# saving item : 치하오
# saving item : 치하오날개
# saving item : 치하오다리
# saving item : 치하오순살
# saving item : 소이바베큐
# saving item : 순살소이바베큐
# saving item : 핫소이바베큐
# saving item : 순살핫소이바베큐
# saving item : 갈비레오
# saving item : 핫갈비레오
# saving item : 붐바스틱
# saving item : 치레카
# saving item : 순살치레카
# saving item : 치레카날개¸
# saving item : 치레카다리¸
# saving item : 커리퀸
# saving item : 순살커리퀸
# saving item : 커리퀸날개¸
# saving item : 커리퀸다리¸
# saving item : 맵스터
# saving item : 순살맵스터
# saving item : 맵스터날개¸
# saving item : 맵스터다리¸
# saving item : 맛초킹（한마리）
# saving item : 순살맛초킹
# saving item : 맛초킹날개¸
# saving item : 맛초킹다리¸
# saving item : 뿌링클
# saving item : 뿌링클날개¸
# saving item : 뿌링클다리¸
# saving item : 뿌링클HOT
# saving item : 순살뿌링클
# saving item : 순살뿌링클HOT
# saving item : 바삭클
# saving item : 순살바삭클
# saving item : 해바라기후라이드치킨
# saving item : 후라이드 반／양념 반
# saving item : 해바라기핫후라이드치킨
# saving item : 해바라기닭다리후라이드치킨
# saving item : 닭날개후라이드
# saving item : 양념치킨
# saving item : 매운맛양념치킨
# saving item : 간장골드한마리
# saving item : 간장골드날개¸
# saving item : 간장골드다리¸
# saving item : 콜팝치킨
# saving item : 미니콜팝
# saving item : 왕콜팝
# saving item : 빅콜팝
# saving item : 뿌링콜팝
# saving item : 뿌링미니콜팝
# saving item : 뿌링왕콜팝
# saving item : 뿌링빅콜팝
# saving item : 뿌링소떡
# saving item : 빨간소떡
# saving item : 뿌링감자
# saving item : 뿌링치즈볼
# saving item : 달콤바삭치즈볼
# saving item : 케이준프라이
# saving item : 뿌링치즈스틱
# saving item : 콜라1.25L¸
# saving item : 사이다1.25L¸
# saving item : 콜라500ml
# saving item : 치킨무
# saving item : 양념소스
# saving item : 머스타드소스
# saving item : 커리딥소스
# saving item : 뿌링뿌링소스
# 금룡-한양대점
# saving item : 짜장
# saving item : 탕수육 小
# saving item : 라조기
# saving item : 유산슬
# saving item : 홍합짬뽕
# saving item : 삼품냉채
# saving item : 짜장
# saving item : 볶음밥
# saving item : 짬뽕
# saving item : 탕짜면
# saving item : 세트1（탕수육＋짜장＋짬뽕）
# saving item : 간짜장
# saving item : 탕볶밥
# saving item : 탕짬면
# saving item : 세트0（탕수육＋짜장2）
# saving item : 군만두
# saving item : 짜장
# saving item : 짬뽕
# saving item : 울면
# saving item : 우동
# saving item : 간짜장
# saving item : 유니짜장
# saving item : 삼선간짜장
# saving item : 삼선짬뽕
# saving item : 삼선우동
# saving item : 삼선울면
# saving item : 기스면
# saving item : 매운짬뽕
# saving item : 굴짬뽕
# saving item : 고추짬뽕
# saving item : 홍합짬뽕
# saving item : 떡볶이 쟁반짜장
# saving item : 떡볶이 볶음짬뽕
# saving item : 누룽지탕
# saving item : 군만두
# saving item : 볶음밥
# saving item : 짬뽕밥
# saving item : 짜장밥
# saving item : 김치볶음밥
# saving item : 잡채밥
# saving item : 새우볶음밥
# saving item : 삼선볶음밥
# saving item : 고추잡채밥
# saving item : 마파두부밥
# saving item : 금룡정식
# saving item : 유산슬밥
# saving item : 잡탕밥
# saving item : 물만두
# saving item : 탕수육 小
# saving item : 탕수육 中
# saving item : 탕수육 大
# saving item : 사천탕수육
# saving item : 라조기
# saving item : 라조육
# saving item : 깐풍기
# saving item : 깐풍육
# saving item : 새우와두부
# saving item : 자연송이와죽순
# saving item : 동고버섯과죽순
# saving item : 고추잡채
# saving item : 유산슬
# saving item : 팔보채
# saving item : 잡탕
# saving item : 전가복
# saving item : 샥스핀
# saving item : 사품냉채
# saving item : 삼품냉채
# saving item : 이품냉채
# saving item : 해파리냉채
# saving item : 해삼과자연송이
# saving item : 해삼탕
# saving item : 라조새우
# saving item : 깐쇼새우
# saving item : 새우와자연송이
# saving item : 소고기탕수육
# saving item : 소고기튀김
# saving item : 술국
# saving item : 당면잡채
# saving item : 마파두부
# saving item : 양장피
# saving item : 난자완스
# saving item : 쟁반짜장 1人
# saving item : 쟁반짜장 2人
# saving item : 돈까스정식
# saving item : 탕짜면
# saving item : 탕짬면
# saving item : 탕볶밥
# saving item : 세트0（탕수육＋짜장2）
# saving item : 세트1（탕수육＋짜장＋짬뽕）
# saving item : 세트2（깐풍육＋짜장＋짬뽕）
# saving item : 세트3（깐풍기＋짜장＋짬뽕）
# saving item : 세트4（탕수육＋쟁반짜장＋군만두 or 물만두）
# saving item : 세트5（양장피＋쟁반짜장＋군만두 or 물만두）
# saving item : 세트6（깐풍기＋쟁반짜장＋군만두 or 물만두）
# saving item : 세트7（팔보채＋쟁반짜장＋군만두 or 물만두）
# saving item : 부추잡채
# saving item : 물냉면
# saving item : 비빔냉면
# saving item : 콩국수
# 멕시카나-성수점
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 땡초치킨
# saving item : 후라이드치킨
# saving item : Mr.김치킨
# saving item : 눈꽃치즈치킨
# saving item : 반반치킨
# saving item : 치토스치킨
# saving item : 투마리세트
# saving item : 순살반반
# saving item : 양념치킨
# saving item : 후라이드치킨
# saving item : 치토스치킨（콘스프맛）
# saving item : 순살치토스치킨
# saving item : 순살세트
# saving item : 땡초치킨
# saving item : Mr.김치킨
# saving item : 강정치킨（뼈）
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 오징어짬뽕치킨
# saving item : 간장땡초치킨
# saving item : 간장마늘치킨
# saving item : 골드치킨（간장）
# saving item : 눈꽃치즈치킨
# saving item : 땡초치킨
# saving item : 마늘치킨
# saving item : 매운양념치킨
# saving item : 양념치킨
# saving item : 허니벌꿀치킨
# saving item : 후라이드치킨
# saving item : 순살Mr.김치킨
# saving item : 순살강정치킨
# saving item : 순살오징어짬뽕치킨
# saving item : 순살골드치킨（간장）
# saving item : 순살눈꽃치즈치킨
# saving item : 순살땡초치킨
# saving item : 순살마늘치킨
# saving item : 순살매운양념치킨
# saving item : 순살양념치킨
# saving item : 순살허니벌꿀치킨
# saving item : 순살후라이드치킨
# saving item : 순살치토스치킨
# saving item : 순살치토스치킨（콘스프맛）
# saving item : 반반치킨
# saving item : 순살반반
# saving item : 투마리세트
# saving item : 순살세트
# saving item : 달콤한윙
# saving item : 달콤한핀
# saving item : 매콤한윙
# saving item : 멕시듀오（다리＋날개）
# saving item : 멕시듀오（간장）
# saving item : 멕시듀오（간장＋양념）
# saving item : 멕시듀오（땡초）
# saving item : 멕시듀오（양념）
# saving item : 멕시듀오（허니벌꿀）
# saving item : 멕시듀오（후라이드＋간장）
# saving item : 멕시듀오（후라이드＋양념）
# saving item : 간장소스윙
# saving item : 멕시윙（간장＋양념）
# saving item : 멕시윙（눈꽃치즈）
# saving item : 멕시윙（땡초）
# saving item : 멕시윙（후라이드）
# saving item : 멕시윙（양념）
# saving item : 멕시핀（후라이드）
# saving item : 멕시핀（간장）
# saving item : 멕시핀（눈꽃치즈）
# saving item : 멕시핀（땡초）
# saving item : 멕시핀（양념）
# saving item : 멕시윙반반（후라이드＋양념）
# saving item : 멕시핀반반（후라이드＋양념）
# saving item : 한입튀김밥
# saving item : 고추튀김
# saving item : 머스터드 소스 추가
# saving item : 멕시감자
# saving item : 모래집땡초大
# saving item : 모래집후라이드大
# saving item : 무추가
# saving item : 사이다 1.25L
# saving item : 새우링
# saving item : 양념소스 추가
# saving item : 엔젤코코소스 추가
# saving item : 체다치즈볼
# saving item : 콜라 1.25L
# saving item : 콜라 500mL
# saving item : 햇반세트
# saving item : 땡초모래집후라이드
# 요리왕
# saving item : 짬뽕
# saving item : 우동
# saving item : 간짜장
# saving item : 삼선짬뽕
# saving item : 삼선울면
# saving item : 삼선우동
# saving item : 짜장
# saving item : 군만두
# saving item : 짬뽕
# saving item : 탕짜면
# saving item : 간짜장
# saving item : B 세트. 탕수육＋짜장＋짬뽕
# saving item : 0-1 세트. 탕수육＋짜장 or 짬뽕
# saving item : 탕볶밥
# saving item : 탕수육정식（탕수육＋볶음밥＋짜장＋짬뽕국물）
# saving item : 탕수육
# saving item : 잡채밥
# saving item : 탕수육정식（탕수육＋볶음밥＋짜장＋짬뽕국물）
# saving item : 깐쇼새우정식（깐쇼새우＋볶음밥＋짜장＋짬뽕국물）
# saving item : 팔보채정식（팔보채＋볶음밥＋짜장＋짬뽕국물）
# saving item : 볶음밥
# saving item : 짬뽕밥
# saving item : 짜장밥
# saving item : 김치볶음밥
# saving item : 오므라이스
# saving item : 제육덮밥
# saving item : 마파두부밥
# saving item : 오징어덮밥
# saving item : 삼선볶음밥
# saving item : 새우볶음밥
# saving item : 송이밥
# saving item : 고추덮밥
# saving item : 요리왕특밥
# saving item : 삼선짬뽕밥
# saving item : 잡탕밥
# saving item : 류산슬밥
# saving item : 고추짬뽕밥
# saving item : 짜장
# saving item : 짬뽕
# saving item : 우동
# saving item : 울면
# saving item : 간짜장
# saving item : 삼선간짜장
# saving item : 기스면
# saving item : 삼선짬뽕
# saving item : 삼선쟁반짜장
# saving item : 해물볶음짬뽕
# saving item : 고추짬뽕
# saving item : 삼선울면
# saving item : 삼선우동
# saving item : 불타는 쟁반짜장
# saving item : 불타는 볶음짬뽕
# saving item : 고기짬뽕
# saving item : 차돌짬뽕
# saving item : 탕수육
# saving item : 사천탕수육
# saving item : 소고기탕수육
# saving item : 해물탕수육
# saving item : 오징어탕수육
# saving item : 유린기
# saving item : 유린육
# saving item : 고기잡채
# saving item : 라조육
# saving item : 라조기
# saving item : 양장피
# saving item : 깐풍기
# saving item : 팔보채
# saving item : 잡탕
# saving item : 고추잡채
# saving item : 해물누룽지탕
# saving item : 난자완스
# saving item : 류산슬
# saving item : 깐쇼새우
# saving item : 깐풍새우
# saving item : 해파리냉채
# saving item : 해삼탕
# saving item : 삼선짬뽕국물
# saving item : 삼선계란탕
# saving item : 해삼쥬스
# saving item : 짜장돈까스
# saving item : 떡만두국
# saving item : 군만두
# saving item : 물만두
# saving item : 왕만두
# saving item : 탕볶밥
# saving item : 탕짜면
# saving item : 탕짬면
# saving item : 볶짜면
# saving item : 볶짬면
# saving item : 짬짜면
# saving item : 우거지갈비탕
# saving item : 육개장
# saving item : 곰탕
# saving item : 설렁탕
# saving item : 양념치킨＋마늘간장
# saving item : 양념치킨＋후라이드
# saving item : 양념치킨＋마늘간장
# saving item : 마늘간장＋후라이드
# saving item : 마늘간장
# saving item : 후라이드
# saving item : 양념치킨
# saving item : 땡초갈릭＋후라이드
# saving item : 치즈스노우퀸＋후라이드
# saving item : 커리양념＋후라이드
# saving item : 후라이드＋후라이드
# saving item : 후라이드＋후라이드
# saving item : 양념치킨＋후라이드
# saving item : 마늘간장＋후라이드
# saving item : 양념치킨＋마늘간장
# saving item : 땡초갈릭＋후라이드
# saving item : 커리양념＋후라이드
# saving item : 치즈스노우퀸＋후라이드
# saving item : 후라이드
# saving item : 양념치킨
# saving item : 마늘간장
# saving item : 땡초갈릭
# saving item : 커리양념
# saving item : 치즈스노우퀸
# saving item : 삼삼세트
# saving item : 수제아삭킹새우（5마리）
# saving item : 수제아삭킹새우（10마리）
# saving item : 수제아삭킹새우（10마리）＋후라이드
# saving item : 국물떡볶이（소）
# saving item : 치즈스틱
# saving item : 황금감자
# saving item : JMT찹쌀치즈봉
# saving item : 콜라 500ml
# saving item : 콜라 1.25L
# saving item : 사이다 1.25L
# saving item : 치킨무
# saving item : 티바양념소스
# saving item : 매운양념소스
# saving item : 크리미양파소스＋생양파채
# saving item : 파채
# saving item : 땡초갈릭소스
# saving item : 떡사리
# 롯데리아-답십리점
# saving item : 와규에디션Ⅱ세트
# saving item : DoubleX2세트
# saving item : NEW홈패밀리팩
# saving item : NEW홈더블팩
# saving item : 와규에디션Ⅱ
# saving item : 한우불고기버거
# saving item : 핫크리스피버거세트
# saving item : DoubleX2세트
# saving item : 새우버거세트
# saving item : 불고기버거세트
# saving item : T-REX버거 세트
# saving item : 불고기버거
# saving item : 모짜렐라인더 버거-베이컨 세트
# saving item : 새우버거
# saving item : 치킨 1조각
# saving item : T-REX버거
# saving item : 와규에디션Ⅱ
# saving item : DoubleX2버거
# saving item : 더블치킨버거
# saving item : 더블클래식치즈버거
# saving item : T-REX버거
# saving item : 비프바베큐버거
# saving item : 모짜렐라인더버거-해쉬
# saving item : 모짜렐라인더버거-더블
# saving item : 모짜렐라인더버거-베이컨
# saving item : AZ오리지널
# saving item : 데리버거
# saving item : 치킨버거
# saving item : 불고기버거
# saving item : 새우버거
# saving item : 원조빅불
# saving item : 한우불고기버거
# saving item : 핫크리스피버거
# saving item : 클래식치즈버거
# saving item : 와규에디션Ⅱ세트
# saving item : DoubleX2세트
# saving item : 더블치킨세트
# saving item : 더블클래식치즈세트
# saving item : T-REX버거 세트
# saving item : 모짜렐라인더 버거-베이컨 세트
# saving item : 모짜렐라인더 버거-해쉬 세트
# saving item : 모짜렐라인더 버거-더블 세트
# saving item : AZ오리지널세트
# saving item : 데리세트
# saving item : 치킨버거세트
# saving item : 불고기버거세트
# saving item : 새우버거세트
# saving item : 원조빅불세트
# saving item : 한우불고기세트
# saving item : 핫크리스피버거세트
# saving item : 클래식치즈버거 세트
# saving item : 해쉬브라운
# saving item : 양념감자
# saving item : 오징어링
# saving item : 치즈스틱
# saving item : 닭도리탕 小
# saving item : 삼계탕 （2마리）
# saving item : 닭도리탕 中
# saving item : 닭도리탕 大
# saving item : 닭도리탕 小
# saving item : 안동찜닭 小
# saving item : 뼈없는찜닭 小
# saving item : 닭도리탕 中
# saving item : 안동찜닭 中
# saving item : 뼈없는찜닭 中
# saving item : 뼈없는 닭도리탕 小
# saving item : 삼계탕 （2마리）
# saving item : 안동찜닭 大
# saving item : 뼈없는 닭도리탕 中
# saving item : 닭도리탕 小
# saving item : 닭도리탕 中
# saving item : 닭도리탕 大
# saving item : 뼈없는 닭도리탕 小
# saving item : 뼈없는 닭도리탕 中
# saving item : 뼈없는 닭도리탕 大
# saving item : 안동찜닭 小
# saving item : 안동찜닭 中
# saving item : 안동찜닭 大
# saving item : 뼈없는찜닭 小
# saving item : 뼈없는찜닭 中
# saving item : 뼈없는찜닭 大
# saving item : 고구마찜닭 小
# saving item : 고구마찜닭 中
# saving item : 고구마찜닭 大
# saving item : 김치떡도리탕 小
# saving item : 김치떡도리탕 中
# saving item : 김치떡도리탕 大
# saving item : 해물찜닭 小
# saving item : 해물찜닭 中
# saving item : 해물찜닭 大
# saving item : 불찜닭 小
# saving item : 불찜닭 中
# saving item : 불찜닭 大
# saving item : 치즈닭도리탕 小
# saving item : 치즈닭도리탕 中
# saving item : 치즈닭도리탕 大
# saving item : 삼계탕 （2마리）
# saving item : 공기밥
# saving item : 주먹＋계란찜
# saving item : 당면 추가
# saving item : 떡사리 추가
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 스프라이트 500mL
# saving item : 스프라이트 1.25L
# 혼술참치
# saving item : 미
# saving item : 선
# saving item : 진
# saving item : 진
# saving item : 선
# saving item : 미
# 대구안지랑곱창막창
# saving item : 직화양념곱창400g
# saving item : 직화양념막창400g
# saving item : 훈제막창400g
# saving item : 곱창전골600g
# saving item : 주먹밥
# saving item : 날치알주먹밥
# saving item : 곱창세트（직화양념곱창＋세트서비스）
# saving item : 반반（양념곱창200g＋훈제막창200g）
# saving item : 막창세트（직화양념막창＋세트서비스）
# saving item : 직화양념곱창400g
# saving item : 반반（양념막창200g＋훈제막창200g）
# saving item : 반반（양념곱창200g＋양념막창200g）
# saving item : 곱창전골600g
# saving item : 염통200g
# saving item : 훈제막창400g
# saving item : 치곱세트（치즈직화양념곱창＋세트서비스）
# saving item : 치즈직화양념곱창400g
# saving item : 직화양념곱창400g
# saving item : 데리야끼막창400g
# saving item : 직화양념막창400g
# saving item : 훈제막창400g
# saving item : 곱창전골600g
# saving item : 반반（양념막창200g＋훈제막창200g）
# saving item : 반반（양념곱창200g＋양념막창200g）
# saving item : 반반（양념곱창200g＋훈제막창200g）
# saving item : 안지랑세트（직화양념곱창＋곱창전골 600g＋세트서비스）
# saving item : 치곱세트（치즈직화양념곱창＋세트서비스）
# saving item : 곱창세트（직화양념곱창＋세트서비스）
# saving item : 막창세트（직화양념막창＋세트서비스）
# saving item : 오막세트400g（데리야끼 오븐막창＋세트서비스）
# saving item : 고불세트（고추장불고기＋세트서비스）
# saving item : 염통200g
# saving item : 음료수
# saving item : 주먹밥
# saving item : 날치알주먹밥
# saving item : 공기밥
# 바다여행
# saving item : 광어
# saving item : 우럭
# saving item : 세트특선（광어＋우럭）
# saving item : 해산물모둠（전복＋해삼＋멍게＋개불＋가리비 또는 석화＋참소라＋새우＋기타계절해산물＋낙지or낙지호롱＋스끼다시5종＋초밥）
# saving item : 개불
# saving item : 멍게
# saving item : 세트특선（광어＋우럭）
# saving item : 세트특선（광어＋우럭＋계절활어＋연어）
# saving item : 세트특선（광어＋연어）
# saving item : 우럭
# saving item : 활어회물회
# saving item : 연어초밥10pcs
# saving item : 광어
# saving item : 해산물모둠（전복＋해삼＋멍게＋개불＋가리비 또는 석화＋참소라＋새우＋기타계절해산물＋낙지or낙지호롱＋스끼다시5종＋초밥）
# saving item : 산낙지
# saving item : 세트특선（우럭＋연어）
# saving item : 모둠회（광어＋우럭＋계절활어＋연어）
# saving item : 광어
# saving item : 우럭
# saving item : 생연어
# saving item : 숭어
# saving item : 전복치（미역치）
# saving item : 놀래미
# saving item : 도미
# saving item : 농어
# saving item : 도다리세꼬시
# saving item : 아나고세꼬시
# saving item : 줄돔세꼬시
# saving item : 대광어
# saving item : 대도미（1.5kg）
# ...
# saving item : 오징어볶음
# saving item : 오삼볶음
# saving item : 골뱅이무침
# saving item : 감자탕
# saving item : 김치감자탕
# saving item : 뼈찜
# saving item : 부대전골
# saving item : 김치전골
# saving item : 만두전골
# saving item : 곱창전골
# saving item : 낙곱전골
# saving item : 불낙전골
# saving item : 불고기전골
# saving item : 쿨피스
# saving item : 콜라 小
# saving item : 사이다 小
# saving item : 콜라 大
# saving item : 사이다 大
# saving item : 생수
# saving item : 참치주먹밥
# saving item : 멸치주먹밥
# saving item : 날치알주먹밥
# saving item : 게란찜
# saving item : 공기밥
# 멕시카나-뚝섬유원지점
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 땡초치킨
# saving item : 후라이드치킨
# saving item : Mr.김치킨
# saving item : 눈꽃치즈치킨
# saving item : 반반치킨
# saving item : 투마리세트
# saving item : 후라이드치킨
# saving item : 순살반반
# saving item : 치토스치킨
# saving item : 치토스치킨（콘스프맛）
# saving item : 양념치킨
# saving item : 순살세트
# saving item : 순살치토스치킨
# saving item : 땡초치킨
# saving item : Mr.김치킨
# saving item : 강정치킨（뼈）
# saving item : 치토스치킨（콘스프맛）
# saving item : 치토스치킨
# saving item : 오징어짬뽕치킨
# saving item : 골드치킨（간장）
# saving item : 눈꽃치즈치킨
# saving item : 땡초치킨
# saving item : 마늘치킨
# saving item : 매운양념치킨
# saving item : 양념치킨
# saving item : 허니벌꿀치킨
# saving item : 후라이드치킨
# saving item : 순살Mr.김치킨
# saving item : 순살강정치킨
# saving item : 순살오징어짬뽕치킨
# saving item : 순살골드치킨（간장）
# saving item : 순살눈꽃치즈치킨
# saving item : 순살땡초치킨
# saving item : 순살마늘치킨
# saving item : 순살매운양념치킨
# saving item : 순살양념치킨
# saving item : 와퍼주니어세트
# saving item : 치즈와퍼주니어세트
# saving item : 불고기와퍼주니어세트
# saving item : 밸런스치킨버거세트
# saving item : BLT뉴올리언스치킨버거세트
# saving item : 뉴올리언스치킨버거세트
# saving item : BLT롱치킨버거세트
# saving item : 롱치킨디럭스세트
# saving item : 불고기롱치킨버거세트
# saving item : 롱치킨버거세트
# saving item : 더블비프불고기세트
# saving item : 불고기버거세트
# saving item : 치즈버거세트
# saving item : 볼케이노칠리X
# saving item : 몬스터X
# saving item : 트러플머쉬룸X
# saving item : 통새우스테이크버거
# saving item : 볼케이노칠리와퍼
# saving item : 몬스터와퍼
# saving item : 콰트로치즈와퍼
# saving item : 통새우와퍼
# saving item : 트러플머쉬룸와퍼
# saving item : 더블와퍼
# saving item : 베이컨치즈와퍼
# saving item : 와퍼
# saving item : 치즈와퍼
# saving item : 불고기와퍼
# saving item : 불고기치즈와퍼
# saving item : 볼케이노칠리와퍼주니어
# saving item : 몬스터와퍼주니어
# saving item : 콰트로치즈와퍼주니어
# saving item : 통새우와퍼주니어
# saving item : 트러플머쉬룸와퍼주니어
# saving item : 와퍼주니어
# saving item : 치즈와퍼주니어
# saving item : 불고기와퍼주니어
# saving item : 밸런스치킨버거
# saving item : BLT뉴올리언스치킨버거
# saving item : 뉴올리언스치킨버거
# saving item : BLT롱치킨버거
# saving item : 롱치킨디럭스
# saving item : 불고기롱치킨버거
# saving item : 롱치킨버거
# saving item : 더블비프불고기
# saving item : 불고기버거
# saving item : 치즈버거
# saving item : 볼케이노칠리프라이
# saving item : 코울슬로
# saving item : 트러플프라이
# saving item : 콘샐러드
# saving item : 치즈프라이
# saving item : 21치즈스틱
# saving item : 어니언링
# saving item : 크리미모짜볼10조각
# saving item : 크리미모짜볼5조각
# saving item : 텐더킹6조각
# saving item : 텐더킹4조각
# saving item : 텐더킹2조각
# saving item : 코코넛쉬림프9조각＋칠리소스
# saving item : 코코넛쉬림프6조각＋칠리소스
# saving item : 코코넛쉬림프3조각＋칠리소스
# saving item : 너겟킹10조각
# saving item : 너겟킹6조각
# saving item : 너겟킹4조각
# saving item : 프렌치프라이 （R）
# saving item : 프렌치프라이 （L）
# saving item : 콜라L
# saving item : 콜라 R
# saving item : 스프라이트L
# saving item : 스프라이트R
# saving item : 제로콜라R
# saving item : 제로콜라L
# saving item : 환타오렌지R
# saving item : 환타오렌지L
# saving item : 미닛메이드
# saving item : 아이스초코
# saving item : 순수（미네랄워터）
# 대한닭발1979
# saving item : 오돌뼈
# saving item : 닭도리탕
# saving item : 무뼈닭발
# saving item : 통뼈닭발
# saving item : 무뼈세트（무뼈닭발＋오돌뼈＋계란찜＋주먹밥）
# saving item : 대한떡볶이
# saving item : 국물닭발세트（국물닭발＋계란찜＋주먹밥）
# saving item : 무뼈닭발＋계란찜＋주먹밥
# saving item : 무뼈세트（무뼈닭발＋오돌뼈＋계란찜＋주먹밥）
# saving item : 무뼈닭발
# saving item : 국물닭발
# saving item : 오돌뼈
# saving item : 해삼
# saving item : 광어＋연어
# saving item : 광어
# saving item : 광어＋우럭
# saving item : 초밥 1인분（10pcs）
# saving item : 우럭
# saving item : 연어회
# saving item : 모듬회
# saving item : 광어＋우럭＋연어
# saving item : 도다리 세꼬시
# saving item : 낙지
# saving item : 모듬회
# saving item : 광어
# saving item : 우럭
# saving item : 광어＋우럭
# saving item : 연어회
# saving item : 광어＋연어
# saving item : 광어＋우럭＋연어
# saving item : 도다리
# saving item : 도미
# saving item : 농어
# saving item : 전어
# saving item : 광어 세꼬시
# saving item : 도다리 세꼬시
# saving item : 멍게
# saving item : 낙지
# saving item : 개불
# saving item : 해삼
# saving item : 오징어회
# saving item : 오징어통찜
# saving item : 초밥 1인분（10pcs）
# saving item : 연어초밥 1인분（10pcs）
# saving item : 회덮밥
# saving item : 매운탕
# saving item : 통우럭탕
# 배달삼겹돼지되지-구의점
# saving item : 오리지날 中
# saving item : 양념 中
# saving item : 반반 中
# saving item : 에네르기 파삼겹 中
# saving item : 별미막국수
# saving item : 오리지날 小
# saving item : 오리지날 솔로
# saving item : 양념 솔로
# saving item : 오리지날 中
# saving item : 오리지날 小
# saving item : 반반 小
# saving item : 반반 中
# saving item : 양념 小
# saving item : 양념 中
# saving item : 오리지날 大
# saving item : 반반 大
# saving item : 별미막국수
# saving item : 나폴리삼겹살 솔로
# saving item : 나폴리삼겹살 小
# saving item : 나폴리삼겹살 中
# saving item : 나폴리삼겹살 大
# saving item : 화이트어니언삼겹살 솔로
# saving item : 화이트어니언삼겹살 小
# saving item : 화이트어니언삼겹살 中
# saving item : 화이트어니언삼겹살 大
# saving item : 오리지날 솔로
# saving item : 오리지날 小
# saving item : 오리지날 中
# saving item : 오리지날 大
# saving item : 양념 솔로
# saving item : 양념 小
# saving item : 양념 中
# saving item : 양념 大
# saving item : 반반 小
# saving item : 반반 中
# saving item : 반반 大
# saving item : 에네르기 파삼겹 솔로
# saving item : 에네르기 파삼겹 小
# saving item : 에네르기 파삼겹 中
# saving item : 에네르기 파삼겹 大
# saving item : 공기밥
# saving item : 쌈 추가
# saving item : 반찬
# saving item : 파절이
# saving item : 쌈무
# saving item : 명이나물
# saving item : 김치찌개
# saving item : 어니언 디핑소스
# saving item : 어니언 칠리 소스
# saving item : 콜라 245mL
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 생수 500mL
# saving item : 모히또
# saving item : 피나콜라다
# 배달삼겹돼지되지-구의점
# saving item : 오리지날 中
# saving item : 양념 中
# saving item : 반반 中
# saving item : 에네르기 파삼겹 中
# saving item : 별미막국수
# saving item : 오리지날 小
# saving item : 오리지날 솔로
# saving item : 양념 솔로
# saving item : 오리지날 中
# saving item : 오리지날 小
# saving item : 반반 小
# saving item : 반반 中
# saving item : 양념 小
# saving item : 양념 中
# saving item : 오리지날 大
# saving item : 반반 大
# saving item : 별미막국수
# saving item : 나폴리삼겹살 솔로
# saving item : 나폴리삼겹살 小
# saving item : 나폴리삼겹살 中
# saving item : 나폴리삼겹살 大
# saving item : 화이트어니언삼겹살 솔로
# saving item : 화이트어니언삼겹살 小
# saving item : 화이트어니언삼겹살 中
# saving item : 화이트어니언삼겹살 大
# saving item : 오리지날 솔로
# saving item : 오리지날 小
# saving item : 오리지날 中
# saving item : 오리지날 大
# saving item : 양념 솔로
# saving item : 양념 小
# saving item : 양념 中
# saving item : 양념 大
# saving item : 반반 小
# saving item : 반반 中
# saving item : 반반 大
# saving item : 에네르기 파삼겹 솔로
# saving item : 에네르기 파삼겹 小
# saving item : 에네르기 파삼겹 中
# saving item : 에네르기 파삼겹 大
# saving item : 공기밥
# saving item : 쌈 추가
# saving item : 반찬
# saving item : 파절이
# saving item : 쌈무
# saving item : 명이나물
# saving item : 김치찌개
# saving item : 어니언 디핑소스
# saving item : 어니언 칠리 소스
# saving item : 콜라 245mL
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 생수 500mL
# saving item : 모히또
# saving item : 피나콜라다
# 7번가피자-한양대점
# saving item : 칠리새우 R
# saving item : 홍대피자 R
# saving item : 체다골드포테이토 R
# saving item : 놀부단호박 R
# saving item : 7번가스페셜 R
# saving item : 깐쇼불갈비 R
# saving item : 슈퍼콤비네이션 R
# saving item : 페페로니 R
# saving item : 흥부 포테이토 R
# saving item : 체다골드포테이토 R
# saving item : 홍대피자 R
# saving item : 슈퍼콤비네이션 L
# saving item : 7번가스페셜 R
# saving item : 깐쇼불갈비 R
# saving item : 리치고구마치킨 R
# saving item : 페페로니 L
# saving item : 깐쇼불갈비 R
# saving item : 칠리새우 R
# saving item : 놀부단호박 R
# saving item : 7번가스페셜 R
# saving item : 홍대피자 R
# saving item : 체다골드포테이토 R
# saving item : 깐쇼불갈비 L
# saving item : 칠리새우 L
# saving item : 놀부단호박 L
# saving item : 7번가스페셜 L
# saving item : 홍대피자 L
# saving item : 체다골드포테이토 L
# saving item : 와이키키 R
# saving item : 리치고구마치킨 R
# saving item : 칠리불갈비 R
# saving item : 언더더시 R
# saving item : 해쉬베이컨 R
# saving item : 고구마피자 R
# saving item : 와이키키 L
# saving item : 리치고구마치킨 L
# saving item : 칠리불갈비 L
# saving item : 언더더시 L
# saving item : 해쉬베이컨 L
# saving item : 고구마피자 L
# saving item : 더블치즈 R
# saving item : 흥부 포테이토 R
# saving item : 불고기 R
# saving item : 슈퍼콤비네이션 R
# saving item : 페페로니 R
# saving item : 더블치즈 L
# saving item : 흥부 포테이토 L
# saving item : 불고기 L
# saving item : 슈퍼콤비네이션 L
# saving item : 페페로니 L
# saving item : 더블치즈 G
# saving item : 흥부 포테이토 G
# saving item : 불고기 G
# saving item : 슈퍼콤비네이션 G
# saving item : 페페로니 G
# saving item : 고르곤졸라
# saving item : 마르게리타
# saving item : 프리미엄 SET BOX （ R ）
# saving item : 프리미엄 SET BOX （ L ）
# saving item : 패밀리 SET BOX （ R ）
# saving item : 패밀리 SET BOX （ L ）
# saving item : 치즈까르보나라
# saving item : 오븐스파게티
# saving item : 치킨오븐텐더（5PCS）
# saving item : 통쌀치킨（8PCS）
# saving item : 화이어윙（4PCS）
# saving item : 핫윙（4PCS）
# saving item : 통통새우링（4PCS）
# saving item : 치즈볼（8PCS）
# saving item : 나폴리샐러드
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 스프라이트 500mL
# saving item : 스프라이트 1.5L
# saving item : 수제피클
# saving item : 디핑소스
# saving item : 치킨샘플러
# saving item : 시즈닝포테이토
# saving item : 핫소스
# 파리바게뜨-뚝섬점
# saving item : 아이스 아메리카노（오리지널）
# saving item : 마이넘버원2
# saving item : 초코반 딸기반 케이크
# saving item : 쫄깃한 토스트
# saving item : 우유가 좋은 뽀로로케익
# saving item : 닭갈비 고로케
# saving item : 후레쉬크림샌드빵
# saving item : 런치 샌드위치
# saving item : 아이스 아메리카노（오리지널）
# saving item : 밤식빵
# saving item : 디럭스 샌드위치
# saving item : 블루베리 베이글
# saving item : 쫄깃한 피자빵
# saving item : 모짜렐라 포카챠
# saving item : 맘모스브레드
# saving item : 추억의 소시지빵
# saving item : 쫄깃한 토스트
# saving item : 우유가 좋은 뽀로로케익
# saving item : 닭갈비 고로케
# saving item : 굿모닝롤
# saving item : 커피번
# saving item : 명품 잡채고로케
# saving item : 찹쌀도넛
# saving item : 초코소라빵
# saving item : 땅콩크림빵
# saving item : 꿀 토스트 플러스
# saving item : 호두 호밀 식빵
# saving item : 그대로토스트
# saving item : 토종효모 정통우유식빵
# saving item : 쫄깃한 피자빵
# saving item : 뽀드득 그릴소시지
# saving item : 추억의 소시지빵
# saving item : 정통크라상
# saving item : 후레쉬 크림빵
# saving item : 블루베리 베이글
# saving item : 야채빵
# saving item : 몬스터치즈번
# saving item : 건포도토종효모빵
# saving item : 단팥도넛
# saving item : 모카빵
# saving item : 후레쉬크림샌드빵
# saving item : 밤식빵
# saving item : 초코 왕소라 플러스
# saving item : 담백하고 쫄깃한 뜯어먹는 식빵
# saving item : 맘모스브레드
# saving item : 옥수수 식빵
# saving item : 모카 크림빵
# saving item : 명품카레 고로케
# saving item : 촉촉한 치즈케익
# saving item : 순수（秀） 담백식빵
# saving item : 우유팥빙수
# saving item : 꽃빙수（딸기／망고）
# saving item : 망고소르베빙수
# saving item : 우유팥빙 더블세트
# saving item : 빙수 커플세트
# saving item : 꽃빙（딸기／망고） 더블세트
# saving item : 우유팥빙 트리플세트（2천원할인가）
# saving item : 달콤 패밀리세트（2천원할인가）
# saving item : 상큼 패밀리세트（2천원할인가）
# saving item : 모짜렐라 포카챠
# saving item : N속이꽉찬치킨클럽샌드위치
# saving item : 통밀 햄에그 샌드위치
# saving item : 디럭스 샌드위치
# saving item : 런치 샌드위치
# saving item : 케이준 치킨샐러드
# saving item : 양송이 스프
# saving item : 스모크드브랏（2개입）
# saving item : 에뚜아르쇼콜라
# saving item : 마이넘버원2
# saving item : 초코반 딸기반 케이크
# saving item : 치즈케이크
# saving item : 촉촉한 블루베리 쉬폰
# saving item : 호두 아몬드파티
# saving item : 러브러브초코
# saving item : 놀이동산 타요와 행복한 시간
